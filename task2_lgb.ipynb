# %%
import pandas as pd

# %%
df_original = pd.read_csv("data/train_data.csv")
n_original = df_original.shape[0]
df_submit = pd.read_csv("data/sample_submission.csv")
df = pd.concat([df_original, df_submit], axis=0).reset_index(drop=True)

# %%
def siRNA_feat_builder(s: pd.Series, anti: bool = False):
    name = "anti" if anti else "sense"
    df = s.to_frame()
    df[f"feat_siRNA_{name}_seq_len"] = s.str.len()
    for pos in [0, -1]:
        for c in list("AUGC"):
            df[f"feat_siRNA_{name}_seq_{c}_{'front' if pos == 0 else 'back'}"] = (
                s.str[pos] == c
            )
    df[f"feat_siRNA_{name}_seq_pattern_1"] = s.str.startswith("AA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_2"] = s.str.startswith("GA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_3"] = s.str.startswith("CA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_4"] = s.str.startswith("UA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_5"] = s.str.startswith("UU") & s.str.endswith(
        "AA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_6"] = s.str.startswith("UU") & s.str.endswith(
        "GA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_7"] = s.str.startswith("UU") & s.str.endswith(
        "CA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_8"] = s.str.startswith("UU") & s.str.endswith(
        "UA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_9"] = s.str[1] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_10"] = s.str[-2] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_GC_frac"] = (
        s.str.contains("G") + s.str.contains("C")
    ) / s.str.len()
    return df.iloc[:, 1:]

# %%
df_publication_id = pd.get_dummies(df.publication_id)
df_publication_id.columns = [
    f"feat_publication_id_{c}" for c in df_publication_id.columns
]
df_gene_target_symbol_name = pd.get_dummies(df.gene_target_symbol_name)
df_gene_target_symbol_name.columns = [
    f"feat_gene_target_symbol_name_{c}" for c in df_gene_target_symbol_name.columns
]
df_gene_target_ncbi_id = pd.get_dummies(df.gene_target_ncbi_id)
df_gene_target_ncbi_id.columns = [
    f"feat_gene_target_ncbi_id_{c}" for c in df_gene_target_ncbi_id.columns
]
df_gene_target_species = pd.get_dummies(df.gene_target_species)
df_gene_target_species.columns = [
    f"feat_gene_target_species_{c}" for c in df_gene_target_species.columns
]
siRNA_duplex_id_values = df.siRNA_duplex_id.str.split("-|\.").str[1].astype("int")
siRNA_duplex_id_values = (siRNA_duplex_id_values - siRNA_duplex_id_values.min()) / (
    siRNA_duplex_id_values.max() - siRNA_duplex_id_values.min()
)
df_siRNA_duplex_id = pd.DataFrame(siRNA_duplex_id_values)
df_cell_line_donor = pd.get_dummies(df.cell_line_donor)
df_cell_line_donor.columns = [
    f"feat_cell_line_donor_{c}" for c in df_cell_line_donor.columns
]
df_cell_line_donor["feat_cell_line_donor_hepatocytes"] = (
    (df.cell_line_donor.str.contains("Hepatocytes")).fillna(False).astype("int")
)
df_cell_line_donor["feat_cell_line_donor_cells"] = (
    df.cell_line_donor.str.contains("Cells").fillna(False).astype("int")
)
df_siRNA_concentration = df.siRNA_concentration.to_frame()
df_Transfection_method = pd.get_dummies(df.Transfection_method)
df_Transfection_method.columns = [
    f"feat_Transfection_method_{c}" for c in df_Transfection_method.columns
]
df_Duration_after_transfection_h = pd.get_dummies(df.Duration_after_transfection_h)
df_Duration_after_transfection_h.columns = [
    f"feat_Duration_after_transfection_h_{c}"
    for c in df_Duration_after_transfection_h.columns
]
feats = pd.concat(
    [
        df_publication_id,
        df_gene_target_symbol_name,
        df_gene_target_ncbi_id,
        df_gene_target_species,
        df_siRNA_duplex_id,
        df_cell_line_donor,
        df_siRNA_concentration,
        df_Transfection_method,
        df_Duration_after_transfection_h,
        siRNA_feat_builder(df.siRNA_sense_seq, False),
        siRNA_feat_builder(df.siRNA_antisense_seq, True),
        df.iloc[:, -1].to_frame(),
    ],
    axis=1,
)

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    feats.iloc[:n_original, :-1],
    feats.iloc[:n_original, -1],
    test_size=0.2,
    random_state=42,
)

# %%
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)


# 定义一个回调函数来打印验证集的结果
def print_validation_result(env):
    result = env.evaluation_result_list[-1]
    print(f"[{env.iteration}] {result[1]}'s {result[0]}: {result[2]}")


params = {
    "boosting_type": "gbdt",
    "objective": "regression",
    "metric": "root_mean_squared_error",
    "max_depth": 7,
    "learning_rate": 0.02,
    "verbose": 0,
}
gbm = lgb.train(
    params,
    train_data,
    num_boost_round=15000,
    valid_sets=[test_data],
    callbacks=[print_validation_result],
)
# Out:
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=7) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=128) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=7) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=128) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=7) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=128) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [0] rmse's valid_0: 35.23799677060255
# [1] rmse's valid_0: 34.977646483970716
# [2] rmse's valid_0: 34.72869468937505
# [3] rmse's valid_0: 34.487358260471446
# [4] rmse's valid_0: 34.24919839421212
# [5] rmse's valid_0: 34.018637106044736
# [6] rmse's valid_0: 33.80449949482096
# [7] rmse's valid_0: 33.610262019348234
# [8] rmse's valid_0: 33.422535315859534
# [9] rmse's valid_0: 33.24152640097391
# [10] rmse's valid_0: 33.05389260405235
# [11] rmse's valid_0: 32.88336974402862
# [12] rmse's valid_0: 32.70630982595257
# [13] rmse's valid_0: 32.54501429756031
# [14] rmse's valid_0: 32.3781109336015
# [15] rmse's valid_0: 32.211169079274576
# [16] rmse's valid_0: 32.05165971191547
# [17] rmse's valid_0: 31.893582363837623
# [18] rmse's valid_0: 31.744520329468862
# [19] rmse's valid_0: 31.593745669725863
# [20] rmse's valid_0: 31.437850204101004
# [21] rmse's valid_0: 31.302863776781795
# [22] rmse's valid_0: 31.16644967253964
# [23] rmse's valid_0: 31.048390871514346
# [24] rmse's valid_0: 30.907263247288245
# [25] rmse's valid_0: 30.791435993279265
# [26] rmse's valid_0: 30.656708607121267
# [27] rmse's valid_0: 30.54754311523407
# [28] rmse's valid_0: 30.42160105817469
# [29] rmse's valid_0: 30.31801082999094
# [30] rmse's valid_0: 30.21977086757736
# [31] rmse's valid_0: 30.101825399654924
# [32] rmse's valid_0: 30.00752141792964
# [33] rmse's valid_0: 29.895810184544604
# [34] rmse's valid_0: 29.806692310382854
# [35] rmse's valid_0: 29.7010803417092
# [36] rmse's valid_0: 29.617205738749472
# [37] rmse's valid_0: 29.533832767243386
# [38] rmse's valid_0: 29.43545483577398
# [39] rmse's valid_0: 29.357543766859376
# [40] rmse's valid_0: 29.26100126342971
# [41] rmse's valid_0: 29.187332546166953
# [42] rmse's valid_0: 29.096209383829915
# [43] rmse's valid_0: 29.026325120841275
# [44] rmse's valid_0: 28.95610551509291
# [45] rmse's valid_0: 28.87175855742694
# [46] rmse's valid_0: 28.806812942256688
# [47] rmse's valid_0: 28.72665970029545
# [48] rmse's valid_0: 28.665577077565942
# [49] rmse's valid_0: 28.589307682042907
# [50] rmse's valid_0: 28.529522762557956
# [51] rmse's valid_0: 28.457075953977302
# [52] rmse's valid_0: 28.401575326703103
# [53] rmse's valid_0: 28.33118326022028
# [54] rmse's valid_0: 28.26594749589642
# [55] rmse's valid_0: 28.193653112068798
# [56] rmse's valid_0: 28.13187549702615
# [57] rmse's valid_0: 28.07034398992779
# [58] rmse's valid_0: 28.009250800403365
# [59] rmse's valid_0: 27.943200053052035
# [60] rmse's valid_0: 27.89222101245669
# [61] rmse's valid_0: 27.829176533109877
# [62] rmse's valid_0: 27.780455165645712
# [63] rmse's valid_0: 27.725726152252484
# [64] rmse's valid_0: 27.678085725914922
# [65] rmse's valid_0: 27.620417737482324
# [66] rmse's valid_0: 27.571020391461836
# [67] rmse's valid_0: 27.520884902225557
# [68] rmse's valid_0: 27.474382414584248
# [69] rmse's valid_0: 27.42341805578269
# [70] rmse's valid_0: 27.382415694994744
# [71] rmse's valid_0: 27.33499923304446
# [72] rmse's valid_0: 27.287140120940894
# [73] rmse's valid_0: 27.241047058503096
# [74] rmse's valid_0: 27.19729706752551
# [75] rmse's valid_0: 27.155024554852087
# [76] rmse's valid_0: 27.1070215032583
# [77] rmse's valid_0: 27.066589670854523
# [78] rmse's valid_0: 27.028076296228225
# [79] rmse's valid_0: 26.98664254547697
# [80] rmse's valid_0: 26.94640383279964
# [81] rmse's valid_0: 26.908305653412977
# [82] rmse's valid_0: 26.871210602338756
# [83] rmse's valid_0: 26.83019151810575
# [84] rmse's valid_0: 26.793232931542878
# [85] rmse's valid_0: 26.763004203361387
# [86] rmse's valid_0: 26.728961725717856
# [87] rmse's valid_0: 26.69891003675002
# [88] rmse's valid_0: 26.665020364769184
# [89] rmse's valid_0: 26.628208505259348
# [90] rmse's valid_0: 26.599533567796072
# [91] rmse's valid_0: 26.568931621425534
# [92] rmse's valid_0: 26.53858785963616
# [93] rmse's valid_0: 26.51274697930688
# [94] rmse's valid_0: 26.48433381548442
# [95] rmse's valid_0: 26.46137399703724
# [96] rmse's valid_0: 26.43282196327232
# [97] rmse's valid_0: 26.412155503535033
# [98] rmse's valid_0: 26.38530789765152
# [99] rmse's valid_0: 26.3663055294461
# [100] rmse's valid_0: 26.342123955549088
# [101] rmse's valid_0: 26.318179527457513
# [102] rmse's valid_0: 26.295384870356305
# [103] rmse's valid_0: 26.266276501166963
# [104] rmse's valid_0: 26.247984580802207
# [105] rmse's valid_0: 26.223572781729082
# [106] rmse's valid_0: 26.206110411841472
# [107] rmse's valid_0: 26.186731578455557
# [108] rmse's valid_0: 26.167297284092463
# [109] rmse's valid_0: 26.14405099116994
# [110] rmse's valid_0: 26.129314970651354
# [111] rmse's valid_0: 26.1066395230603
# [112] rmse's valid_0: 26.07578693025052
# [113] rmse's valid_0: 26.060365703003956
# [114] rmse's valid_0: 26.04623981952582
# [115] rmse's valid_0: 26.02112897445375
# [116] rmse's valid_0: 25.990758602013468
# [117] rmse's valid_0: 25.967541830263503
# [118] rmse's valid_0: 25.947083913803148
# [119] rmse's valid_0: 25.916238867435204
# [120] rmse's valid_0: 25.890618588014707
# [121] rmse's valid_0: 25.86700804493336
# [122] rmse's valid_0: 25.84577376705672
# [123] rmse's valid_0: 25.830115778500417
# [124] rmse's valid_0: 25.80986443716241
# [125] rmse's valid_0: 25.787880639804616
# [126] rmse's valid_0: 25.775893694860276
# [127] rmse's valid_0: 25.756136244874554
# [128] rmse's valid_0: 25.738155659997727
# [129] rmse's valid_0: 25.72230617653666
# [130] rmse's valid_0: 25.703378584423984
# [131] rmse's valid_0: 25.684974197129417
# [132] rmse's valid_0: 25.669255006266493
# [133] rmse's valid_0: 25.6501235435815
# [134] rmse's valid_0: 25.637663428821856
# [135] rmse's valid_0: 25.61943991539337
# [136] rmse's valid_0: 25.602395979517834
# [137] rmse's valid_0: 25.587006352746254
# [138] rmse's valid_0: 25.57151822490118
# [139] rmse's valid_0: 25.55514036716679
# [140] rmse's valid_0: 25.53839449841061
# [141] rmse's valid_0: 25.522902790347146
# [142] rmse's valid_0: 25.510249847105282
# [143] rmse's valid_0: 25.49198939134205
# [144] rmse's valid_0: 25.477282552421322
# [145] rmse's valid_0: 25.459042819090953
# [146] rmse's valid_0: 25.43939332401652
# [147] rmse's valid_0: 25.425678607184118
# [148] rmse's valid_0: 25.408984832631397
# [149] rmse's valid_0: 25.394864678660362
# [150] rmse's valid_0: 25.378838828262406
# [151] rmse's valid_0: 25.36194005037887
# [152] rmse's valid_0: 25.347680129814222
# [153] rmse's valid_0: 25.335438873837933
# [154] rmse's valid_0: 25.308991720475603
# [155] rmse's valid_0: 25.296998023459064
# [156] rmse's valid_0: 25.288118855784937
# [157] rmse's valid_0: 25.262900827075963
# [158] rmse's valid_0: 25.246014128279025
# [159] rmse's valid_0: 25.234403847236386
# [160] rmse's valid_0: 25.219509710923617
# [161] rmse's valid_0: 25.195330549272704
# [162] rmse's valid_0: 25.184420659071346
# [163] rmse's valid_0: 25.175898597495458
# [164] rmse's valid_0: 25.158696602545906
# [165] rmse's valid_0: 25.140857745012635
# [166] rmse's valid_0: 25.12729171909505
# [167] rmse's valid_0: 25.109723990563108
# [168] rmse's valid_0: 25.100049867027373
# [169] rmse's valid_0: 25.089087814401523
# [170] rmse's valid_0: 25.080576865115397
# [171] rmse's valid_0: 25.071394113009625
# [172] rmse's valid_0: 25.05968481923006
# [173] rmse's valid_0: 25.048400334625015
# [174] rmse's valid_0: 25.039358401317127
# [175] rmse's valid_0: 25.024405366187985
# [176] rmse's valid_0: 25.01648962400904
# [177] rmse's valid_0: 25.008031855268136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178] rmse's valid_0: 25.001745335320937
# [179] rmse's valid_0: 24.989489664370833
# [180] rmse's valid_0: 24.98080046697696
# [181] rmse's valid_0: 24.973317918187863
# [182] rmse's valid_0: 24.965938822419826
# [183] rmse's valid_0: 24.944288885066392
# [184] rmse's valid_0: 24.933619774941054
# [185] rmse's valid_0: 24.922976109658844
# [186] rmse's valid_0: 24.91506285375275
# [187] rmse's valid_0: 24.90270935865833
# [188] rmse's valid_0: 24.8970325651503
# [189] rmse's valid_0: 24.89029120496078
# [190] rmse's valid_0: 24.874884107583185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191] rmse's valid_0: 24.861259410565403
# [192] rmse's valid_0: 24.847737087891097
# [193] rmse's valid_0: 24.83929118184582
# [194] rmse's valid_0: 24.82795988761751
# [195] rmse's valid_0: 24.823393304718604
# [196] rmse's valid_0: 24.8096259358207
# [197] rmse's valid_0: 24.79823621657731
# [198] rmse's valid_0: 24.784258307393355
# [199] rmse's valid_0: 24.77261463752924
# [200] rmse's valid_0: 24.768363783476627
# [201] rmse's valid_0: 24.752565004501953
# [202] rmse's valid_0: 24.742357152551467
# [203] rmse's valid_0: 24.731469776156448
# [204] rmse's valid_0: 24.719470195229203
# [205] rmse's valid_0: 24.707046199565035
# [206] rmse's valid_0: 24.694064703142594
# [207] rmse's valid_0: 24.68989213794351
# [208] rmse's valid_0: 24.68145665695046
# [209] rmse's valid_0: 24.66662123745166
# [210] rmse's valid_0: 24.65851214569145
# [211] rmse's valid_0: 24.650515527068734
# [212] rmse's valid_0: 24.639703537705014
# [213] rmse's valid_0: 24.633509269043472
# [214] rmse's valid_0: 24.62530691185373
# [215] rmse's valid_0: 24.617398415899906
# [216] rmse's valid_0: 24.61120172900776
# [217] rmse's valid_0: 24.60189963771811
# [218] rmse's valid_0: 24.591654995987863
# [219] rmse's valid_0: 24.584734855385403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220] rmse's valid_0: 24.577576483196864
# [221] rmse's valid_0: 24.568276751616143
# [222] rmse's valid_0: 24.559278703965568
# [223] rmse's valid_0: 24.55527384837614
# [224] rmse's valid_0: 24.551044372746517
# [225] rmse's valid_0: 24.548364355331607
# [226] rmse's valid_0: 24.540247200043538
# [227] rmse's valid_0: 24.5355437007723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228] rmse's valid_0: 24.52701193168841
# [229] rmse's valid_0: 24.515602303529626
# [230] rmse's valid_0: 24.507632983772673
# [231] rmse's valid_0: 24.49891649020467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232] rmse's valid_0: 24.49611008033721
# [233] rmse's valid_0: 24.489041088725678
# [234] rmse's valid_0: 24.480602784443366
# [235] rmse's valid_0: 24.475583291792226
# [236] rmse's valid_0: 24.46836659242486
# [237] rmse's valid_0: 24.46096810461462
# [238] rmse's valid_0: 24.45474599862515
# [239] rmse's valid_0: 24.450661702794463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240] rmse's valid_0: 24.44650072560901
# [241] rmse's valid_0: 24.440504543438927
# [242] rmse's valid_0: 24.43160937229046
# [243] rmse's valid_0: 24.426692963720292
# [244] rmse's valid_0: 24.421441557286567
# [245] rmse's valid_0: 24.413408562586735
# [246] rmse's valid_0: 24.408178201810124
# [247] rmse's valid_0: 24.40225923800499
# [248] rmse's valid_0: 24.398704034365153
# [249] rmse's valid_0: 24.383642496156927
# [250] rmse's valid_0: 24.37558512047051
# [251] rmse's valid_0: 24.366129368164117
# [252] rmse's valid_0: 24.35694283343002
# [253] rmse's valid_0: 24.352943103867286
# [254] rmse's valid_0: 24.349473663349258
# [255] rmse's valid_0: 24.341394382923326
# [256] rmse's valid_0: 24.333620310112014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257] rmse's valid_0: 24.330177475921655
# [258] rmse's valid_0: 24.32185887681035
# [259] rmse's valid_0: 24.313497606665834
# [260] rmse's valid_0: 24.30978417137997
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261] rmse's valid_0: 24.30750148243567
# [262] rmse's valid_0: 24.303891302031555
# [263] rmse's valid_0: 24.29506743837748
# [264] rmse's valid_0: 24.29175507630946
# [265] rmse's valid_0: 24.28381595802565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266] rmse's valid_0: 24.27974162711745
# [267] rmse's valid_0: 24.27193850771428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268] rmse's valid_0: 24.268702045505552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269] rmse's valid_0: 24.26491588351993
# [270] rmse's valid_0: 24.261963139017215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271] rmse's valid_0: 24.25729098201789
# [272] rmse's valid_0: 24.250251369382333
# [273] rmse's valid_0: 24.245887483395723
# [274] rmse's valid_0: 24.241557222838075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275] rmse's valid_0: 24.237571385992855
# [276] rmse's valid_0: 24.231600263328378
# [277] rmse's valid_0: 24.227918430303326
# [278] rmse's valid_0: 24.224418072645065
# [279] rmse's valid_0: 24.21697991274171
# [280] rmse's valid_0: 24.214098809042866
# [281] rmse's valid_0: 24.208556341355308
# [282] rmse's valid_0: 24.203010170068953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283] rmse's valid_0: 24.19990342791258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284] rmse's valid_0: 24.196674904458447
# [285] rmse's valid_0: 24.190577775376944
# [286] rmse's valid_0: 24.18571450300755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287] rmse's valid_0: 24.178452897550798
# [288] rmse's valid_0: 24.173941512194443
# [289] rmse's valid_0: 24.17143101105072
# [290] rmse's valid_0: 24.163153296240512
# [291] rmse's valid_0: 24.157014027931595
# [292] rmse's valid_0: 24.151626866496187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293] rmse's valid_0: 24.148633669646333
# [294] rmse's valid_0: 24.141048954538096
# [295] rmse's valid_0: 24.12893637796473
# [296] rmse's valid_0: 24.12431953402614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297] rmse's valid_0: 24.121561329461322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298] rmse's valid_0: 24.11841648025894
# [299] rmse's valid_0: 24.111045410181184
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300] rmse's valid_0: 24.107254185078453
# [301] rmse's valid_0: 24.1045517403546
# [302] rmse's valid_0: 24.101100640908232
# [303] rmse's valid_0: 24.09314671548801
# [304] rmse's valid_0: 24.08615232599534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305] rmse's valid_0: 24.083516987694686
# [306] rmse's valid_0: 24.079004375425786
# [307] rmse's valid_0: 24.070030365535054
# [308] rmse's valid_0: 24.063391696434998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309] rmse's valid_0: 24.060691269866304
# [310] rmse's valid_0: 24.055755344192946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311] rmse's valid_0: 24.053352981100215
# [312] rmse's valid_0: 24.049079858033448
# [313] rmse's valid_0: 24.04708034974904
# [314] rmse's valid_0: 24.036487770747428
# [315] rmse's valid_0: 24.032409991981986
# [316] rmse's valid_0: 24.02928998567754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317] rmse's valid_0: 24.02326750744795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318] rmse's valid_0: 24.020620681855227
# [319] rmse's valid_0: 24.016914153892046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320] rmse's valid_0: 24.013000428113866
# [321] rmse's valid_0: 24.00494490030537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322] rmse's valid_0: 24.001524620699477
# [323] rmse's valid_0: 23.997349046065505
# [324] rmse's valid_0: 23.99579613395693
# [325] rmse's valid_0: 23.98797694624164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326] rmse's valid_0: 23.982419306454112
# [327] rmse's valid_0: 23.97791928210522
# [328] rmse's valid_0: 23.967450548159352
# [329] rmse's valid_0: 23.962989047875233
# [330] rmse's valid_0: 23.960676683018853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331] rmse's valid_0: 23.958690603458095
# [332] rmse's valid_0: 23.954441251789167
# [333] rmse's valid_0: 23.94999457801295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334] rmse's valid_0: 23.944792453557735
# [335] rmse's valid_0: 23.939843050641905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [767] rmse's valid_0: 22.694425641343887
# [768] rmse's valid_0: 22.69276659761213
# [769] rmse's valid_0: 22.691589166112173
# [770] rmse's valid_0: 22.690563211518832
# [771] rmse's valid_0: 22.688444116300477
# [772] rmse's valid_0: 22.687067942505415
# [773] rmse's valid_0: 22.686086918620347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [774] rmse's valid_0: 22.685906715613932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [775] rmse's valid_0: 22.684944531789355
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [776] rmse's valid_0: 22.68414651990533
# [777] rmse's valid_0: 22.67954898026249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [778] rmse's valid_0: 22.676942353359493
# [779] rmse's valid_0: 22.67634689418273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [780] rmse's valid_0: 22.6735842500347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [781] rmse's valid_0: 22.6724164288644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [782] rmse's valid_0: 22.671122614931186
# [783] rmse's valid_0: 22.66612776811145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [784] rmse's valid_0: 22.66488474834588
# [785] rmse's valid_0: 22.66424792120968
# [786] rmse's valid_0: 22.662220218019804
# [787] rmse's valid_0: 22.66112031404955
# [788] rmse's valid_0: 22.659911615269568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [789] rmse's valid_0: 22.659022658745773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [790] rmse's valid_0: 22.65670244716892
# [791] rmse's valid_0: 22.652076021689233
# [792] rmse's valid_0: 22.65088415648395
# [793] rmse's valid_0: 22.64759588780163
# [794] rmse's valid_0: 22.64591170455202
# [795] rmse's valid_0: 22.64360334966418
# [796] rmse's valid_0: 22.64250385228816
# [797] rmse's valid_0: 22.639186738134192
# [798] rmse's valid_0: 22.637615759937948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [799] rmse's valid_0: 22.636494665717386
# [800] rmse's valid_0: 22.634574558751133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [801] rmse's valid_0: 22.63396662300354
# [802] rmse's valid_0: 22.632117612097783
# [803] rmse's valid_0: 22.62653050993359
# [804] rmse's valid_0: 22.62556165596535
# [805] rmse's valid_0: 22.620988292975532
# [806] rmse's valid_0: 22.617611767208
# [807] rmse's valid_0: 22.61653049377219
# [808] rmse's valid_0: 22.615095789005355
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [809] rmse's valid_0: 22.613944421356294
# [810] rmse's valid_0: 22.61322658219007
# [811] rmse's valid_0: 22.61063652483923
# [812] rmse's valid_0: 22.609358593213823
# [813] rmse's valid_0: 22.60888281201577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [814] rmse's valid_0: 22.60849940481985
# [815] rmse's valid_0: 22.602464544687543
# [816] rmse's valid_0: 22.59961647472277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [817] rmse's valid_0: 22.598227514288794
# [818] rmse's valid_0: 22.596866736382093
# [819] rmse's valid_0: 22.594440584573487
# [820] rmse's valid_0: 22.59283745301458
# [821] rmse's valid_0: 22.592266409635535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [822] rmse's valid_0: 22.591984191033074
# [823] rmse's valid_0: 22.59080923890364
# [824] rmse's valid_0: 22.590717802982656
# [825] rmse's valid_0: 22.5901875895413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [826] rmse's valid_0: 22.59018630905816
# [827] rmse's valid_0: 22.588952668482186
# [828] rmse's valid_0: 22.586583173005735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [829] rmse's valid_0: 22.586535245246967
# [830] rmse's valid_0: 22.583820981560457
# [831] rmse's valid_0: 22.582677692065687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [832] rmse's valid_0: 22.581745535362238
# [833] rmse's valid_0: 22.579904517885254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [834] rmse's valid_0: 22.57914775745105
# [835] rmse's valid_0: 22.57889068116431
# [836] rmse's valid_0: 22.577546538061323
# ...
# [14788] rmse's valid_0: 20.192726227177943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14789] rmse's valid_0: 20.192690975069045
# [14790] rmse's valid_0: 20.19264059746752
# [14791] rmse's valid_0: 20.192883061722952
# [14792] rmse's valid_0: 20.193011669490318
# [14793] rmse's valid_0: 20.192945242230874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14794] rmse's valid_0: 20.192896892403446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14795] rmse's valid_0: 20.192882620873277
# [14796] rmse's valid_0: 20.192785598417608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14797] rmse's valid_0: 20.19288639069692
# [14798] rmse's valid_0: 20.19306767469006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14799] rmse's valid_0: 20.193093050345375
# [14800] rmse's valid_0: 20.19308131646545
# [14801] rmse's valid_0: 20.19310653858838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14802] rmse's valid_0: 20.19304577839645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14803] rmse's valid_0: 20.19305351429475
# [14804] rmse's valid_0: 20.19285369245932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14805] rmse's valid_0: 20.192932144612158
# [14806] rmse's valid_0: 20.192777470102573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14807] rmse's valid_0: 20.192691325440425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14808] rmse's valid_0: 20.192463030216473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14809] rmse's valid_0: 20.192455084540082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14810] rmse's valid_0: 20.19245905436463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14811] rmse's valid_0: 20.192385304131914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14812] rmse's valid_0: 20.192386991587185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14813] rmse's valid_0: 20.192355250228786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14814] rmse's valid_0: 20.19208956732313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14815] rmse's valid_0: 20.191731725777114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14816] rmse's valid_0: 20.191589213317016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14817] rmse's valid_0: 20.19157455446329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14818] rmse's valid_0: 20.191416508451084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14819] rmse's valid_0: 20.19132132860024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14820] rmse's valid_0: 20.191063914913112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14821] rmse's valid_0: 20.19109224214797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14822] rmse's valid_0: 20.19088980354653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14823] rmse's valid_0: 20.190714286578586
# [14824] rmse's valid_0: 20.190751941681185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14825] rmse's valid_0: 20.190448269398104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14826] rmse's valid_0: 20.190506027710466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14827] rmse's valid_0: 20.190524994873673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14828] rmse's valid_0: 20.190441310686655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14829] rmse's valid_0: 20.190192183137434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14830] rmse's valid_0: 20.19005627270489
# [14831] rmse's valid_0: 20.189805663632512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14832] rmse's valid_0: 20.189665128155507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14833] rmse's valid_0: 20.189824617964778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14834] rmse's valid_0: 20.18983481379833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14835] rmse's valid_0: 20.189843185272405
# [14836] rmse's valid_0: 20.190009303571333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14837] rmse's valid_0: 20.190007700055784
# [14838] rmse's valid_0: 20.18991464964418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14839] rmse's valid_0: 20.189895733134005
# [14840] rmse's valid_0: 20.190032197872366
# [14841] rmse's valid_0: 20.18994544454406
# [14842] rmse's valid_0: 20.189932240499456
# [14843] rmse's valid_0: 20.189618689623757
# [14844] rmse's valid_0: 20.189515655118345
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14845] rmse's valid_0: 20.1893173166477
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14846] rmse's valid_0: 20.18930637433586
# [14847] rmse's valid_0: 20.18939941867866
# [14848] rmse's valid_0: 20.189408415175627
# [14849] rmse's valid_0: 20.189628891230935
# [14850] rmse's valid_0: 20.18972212767966
# [14851] rmse's valid_0: 20.189911189826255
# [14852] rmse's valid_0: 20.1898970501658
# [14853] rmse's valid_0: 20.18997968732786
# [14854] rmse's valid_0: 20.190126980155966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14855] rmse's valid_0: 20.19015542682615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14856] rmse's valid_0: 20.190146820516446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14857] rmse's valid_0: 20.19009992822617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14858] rmse's valid_0: 20.190111628033954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14859] rmse's valid_0: 20.190238157462055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14860] rmse's valid_0: 20.190191768891484
# [14861] rmse's valid_0: 20.19019978868403
# [14862] rmse's valid_0: 20.189790576667303
# [14863] rmse's valid_0: 20.1896577529211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14864] rmse's valid_0: 20.189664333651844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14865] rmse's valid_0: 20.189680189726094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14866] rmse's valid_0: 20.189676098314386
# [14867] rmse's valid_0: 20.189654043894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14868] rmse's valid_0: 20.189598066492604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14869] rmse's valid_0: 20.189454956075213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14870] rmse's valid_0: 20.18933075041749
# [14871] rmse's valid_0: 20.189514654192013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14872] rmse's valid_0: 20.189489881186212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14873] rmse's valid_0: 20.189514751336734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14874] rmse's valid_0: 20.1895574972243
# [14875] rmse's valid_0: 20.18969372359038
# [14876] rmse's valid_0: 20.189163041412172
# [14877] rmse's valid_0: 20.1893464103693
# [14878] rmse's valid_0: 20.188810801176615
# [14879] rmse's valid_0: 20.18885856540705
# [14880] rmse's valid_0: 20.188902449814094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14881] rmse's valid_0: 20.189011794814324
# [14882] rmse's valid_0: 20.18896901420122
# [14883] rmse's valid_0: 20.188879491801867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14884] rmse's valid_0: 20.188958500478755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14885] rmse's valid_0: 20.188948500365473
# [14886] rmse's valid_0: 20.189185142902755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14887] rmse's valid_0: 20.189132876859606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14888] rmse's valid_0: 20.189141115974962
# [14889] rmse's valid_0: 20.189147630848456
# [14890] rmse's valid_0: 20.188998336125614
# [14891] rmse's valid_0: 20.188803345897487
# [14892] rmse's valid_0: 20.188958019709766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14893] rmse's valid_0: 20.188881275263945
# [14894] rmse's valid_0: 20.18881942105068
# [14895] rmse's valid_0: 20.188719658178805
# [14896] rmse's valid_0: 20.188525396163467
# [14897] rmse's valid_0: 20.188636015272415
# [14898] rmse's valid_0: 20.188526492428768
# [14899] rmse's valid_0: 20.188453383514243
# [14900] rmse's valid_0: 20.188543792940784
# [14901] rmse's valid_0: 20.1885895512173
# [14902] rmse's valid_0: 20.1886810024827
# [14903] rmse's valid_0: 20.188872220048825
# [14904] rmse's valid_0: 20.188959485574085
# [14905] rmse's valid_0: 20.189118878089428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14906] rmse's valid_0: 20.189151017917627
# [14907] rmse's valid_0: 20.189258163091207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14908] rmse's valid_0: 20.189163952637937
# [14909] rmse's valid_0: 20.189123913902804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14910] rmse's valid_0: 20.189076052755514
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14911] rmse's valid_0: 20.189025732293377
# [14912] rmse's valid_0: 20.1894628375623
# [14913] rmse's valid_0: 20.18938681301524
# [14914] rmse's valid_0: 20.189417076546967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14915] rmse's valid_0: 20.189428162982185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14916] rmse's valid_0: 20.189364840348553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14917] rmse's valid_0: 20.18938942084881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14918] rmse's valid_0: 20.189397996695995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14919] rmse's valid_0: 20.189371632547378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14920] rmse's valid_0: 20.189480540624615
# [14921] rmse's valid_0: 20.189631262205907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14922] rmse's valid_0: 20.18969156897175
# [14923] rmse's valid_0: 20.189641296657193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14924] rmse's valid_0: 20.189754950612006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14925] rmse's valid_0: 20.189562639519202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14926] rmse's valid_0: 20.189518168539486
# [14927] rmse's valid_0: 20.189405105801477
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14928] rmse's valid_0: 20.189480419603225
# [14929] rmse's valid_0: 20.18935543964017
# [14930] rmse's valid_0: 20.189487062403707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14931] rmse's valid_0: 20.189448954344744
# [14932] rmse's valid_0: 20.189621051815056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14933] rmse's valid_0: 20.189673872820343
# [14934] rmse's valid_0: 20.189962423580695
# [14935] rmse's valid_0: 20.189885395726286
# [14936] rmse's valid_0: 20.190154682225614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14937] rmse's valid_0: 20.190123445346842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14938] rmse's valid_0: 20.190091291807974
# [14939] rmse's valid_0: 20.190120766117595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14940] rmse's valid_0: 20.19011478371637
# [14941] rmse's valid_0: 20.19003331528188
# [14942] rmse's valid_0: 20.189939035478044
# [14943] rmse's valid_0: 20.18985569504961
# [14944] rmse's valid_0: 20.190059759205074
# [14945] rmse's valid_0: 20.190301289072554
# [14946] rmse's valid_0: 20.190572298229057
# [14947] rmse's valid_0: 20.19067287543994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14948] rmse's valid_0: 20.190729084882136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14949] rmse's valid_0: 20.19081438503147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14950] rmse's valid_0: 20.19077322112008
# [14951] rmse's valid_0: 20.190628337436923
# [14952] rmse's valid_0: 20.19038275767446
# [14953] rmse's valid_0: 20.190211275637488
# [14954] rmse's valid_0: 20.18971979726917
# [14955] rmse's valid_0: 20.189661148881164
# [14956] rmse's valid_0: 20.189473616411647
# [14957] rmse's valid_0: 20.189295464178034
# [14958] rmse's valid_0: 20.188743981183503
# [14959] rmse's valid_0: 20.18855610648885
# [14960] rmse's valid_0: 20.18837530746455
# [14961] rmse's valid_0: 20.18819731671028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14962] rmse's valid_0: 20.18807852346639
# [14963] rmse's valid_0: 20.18792463415479
# [14964] rmse's valid_0: 20.187335848086384
# [14965] rmse's valid_0: 20.18724617657228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14966] rmse's valid_0: 20.18717670525309
# [14967] rmse's valid_0: 20.187027253105295
# [14968] rmse's valid_0: 20.186993909417673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14969] rmse's valid_0: 20.18699775849903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14970] rmse's valid_0: 20.186975159209013
# [14971] rmse's valid_0: 20.186877399131596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14972] rmse's valid_0: 20.18695998703788
# [14973] rmse's valid_0: 20.186793645189304
# [14974] rmse's valid_0: 20.18679335292797
# [14975] rmse's valid_0: 20.186946605491524
# [14976] rmse's valid_0: 20.186880308844216
# [14977] rmse's valid_0: 20.18685964069672
# [14978] rmse's valid_0: 20.18683351434489
# [14979] rmse's valid_0: 20.18674834546398
# [14980] rmse's valid_0: 20.18672451438357
# [14981] rmse's valid_0: 20.186726992404175
# [14982] rmse's valid_0: 20.186659638817872
# [14983] rmse's valid_0: 20.18660146684613
# [14984] rmse's valid_0: 20.186585013571783
# [14985] rmse's valid_0: 20.186613784453925
# [14986] rmse's valid_0: 20.186793385596584
# [14987] rmse's valid_0: 20.186676465924695
# [14988] rmse's valid_0: 20.18677405761413
# [14989] rmse's valid_0: 20.186346050438626
# [14990] rmse's valid_0: 20.186250746153696
# [14991] rmse's valid_0: 20.18629990772902
# [14992] rmse's valid_0: 20.186148079169392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14993] rmse's valid_0: 20.186138246429923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14994] rmse's valid_0: 20.186028312536404
# [14995] rmse's valid_0: 20.18590087480316
# [14996] rmse's valid_0: 20.18594431926547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14997] rmse's valid_0: 20.185862129066404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14998] rmse's valid_0: 20.185831603693135
# [14999] rmse's valid_0: 20.185827753407327

# %%
y_pred = gbm.predict(feats.iloc[n_original:, :-1])

# %%
df_submit["mRNA_remaining_pct"] = y_pred
df_submit.to_csv("submission.csv", index=False)
