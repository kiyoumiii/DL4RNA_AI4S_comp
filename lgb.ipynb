# %%
import pandas as pd

# %%
df_original = pd.read_csv("data/train_data.csv")
n_original = df_original.shape[0]
df_submit = pd.read_csv("data/sample_submission.csv")
df = pd.concat([df_original, df_submit], axis=0).reset_index(drop=True)

# %%
def siRNA_feat_builder(s: pd.Series, anti: bool = False):
    name = "anti" if anti else "sense"
    df = s.to_frame()
    df[f"feat_siRNA_{name}_seq_len"] = s.str.len()
    for pos in [0, -1]:
        for c in list("AUGC"):
            df[f"feat_siRNA_{name}_seq_{c}_{'front' if pos == 0 else 'back'}"] = (
                s.str[pos] == c
            )
    df[f"feat_siRNA_{name}_seq_pattern_1"] = s.str.startswith("AA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_2"] = s.str.startswith("GA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_3"] = s.str.startswith("CA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_4"] = s.str.startswith("UA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_5"] = s.str.startswith("UU") & s.str.endswith(
        "AA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_6"] = s.str.startswith("UU") & s.str.endswith(
        "GA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_7"] = s.str.startswith("UU") & s.str.endswith(
        "CA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_8"] = s.str.startswith("UU") & s.str.endswith(
        "UA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_9"] = s.str[1] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_10"] = s.str[-2] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_GC_frac"] = (
        s.str.contains("G") + s.str.contains("C")
    ) / s.str.len()
    return df.iloc[:, 1:]

# %%
df_publication_id = pd.get_dummies(df.publication_id)
df_publication_id.columns = [
    f"feat_publication_id_{c}" for c in df_publication_id.columns
]
df_gene_target_symbol_name = pd.get_dummies(df.gene_target_symbol_name)
df_gene_target_symbol_name.columns = [
    f"feat_gene_target_symbol_name_{c}" for c in df_gene_target_symbol_name.columns
]
df_gene_target_ncbi_id = pd.get_dummies(df.gene_target_ncbi_id)
df_gene_target_ncbi_id.columns = [
    f"feat_gene_target_ncbi_id_{c}" for c in df_gene_target_ncbi_id.columns
]
df_gene_target_species = pd.get_dummies(df.gene_target_species)
df_gene_target_species.columns = [
    f"feat_gene_target_species_{c}" for c in df_gene_target_species.columns
]
siRNA_duplex_id_values = df.siRNA_duplex_id.str[3:-2].str.strip(".").astype("int")
siRNA_duplex_id_values = (siRNA_duplex_id_values - siRNA_duplex_id_values.min()) / (
    siRNA_duplex_id_values.max() - siRNA_duplex_id_values.min()
)
df_siRNA_duplex_id = pd.DataFrame(siRNA_duplex_id_values)
df_cell_line_donor = pd.get_dummies(df.cell_line_donor)
df_cell_line_donor.columns = [
    f"feat_cell_line_donor_{c}" for c in df_cell_line_donor.columns
]
df_cell_line_donor["feat_cell_line_donor_hepatocytes"] = (
    (df.cell_line_donor.str.contains("Hepatocytes")).fillna(False).astype("int")
)
df_cell_line_donor["feat_cell_line_donor_cells"] = (
    df.cell_line_donor.str.contains("Cells").fillna(False).astype("int")
)
df_siRNA_concentration = df.siRNA_concentration.to_frame()
df_Transfection_method = pd.get_dummies(df.Transfection_method)
df_Transfection_method.columns = [
    f"feat_Transfection_method_{c}" for c in df_Transfection_method.columns
]
df_Duration_after_transfection_h = pd.get_dummies(df.Duration_after_transfection_h)
df_Duration_after_transfection_h.columns = [
    f"feat_Duration_after_transfection_h_{c}"
    for c in df_Duration_after_transfection_h.columns
]
feats = pd.concat(
    [
        df_publication_id,
        df_gene_target_symbol_name,
        df_gene_target_ncbi_id,
        df_gene_target_species,
        df_siRNA_duplex_id,
        df_cell_line_donor,
        df_siRNA_concentration,
        df_Transfection_method,
        df_Duration_after_transfection_h,
        siRNA_feat_builder(df.siRNA_sense_seq, False),
        siRNA_feat_builder(df.siRNA_antisense_seq, True),
        df.iloc[:, -1].to_frame(),
    ],
    axis=1,
)

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    feats.iloc[:n_original, :-1],
    feats.iloc[:n_original, -1],
    test_size=0.2,
    random_state=42,
)

# %%
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)


# 定义一个回调函数来打印验证集的结果
def print_validation_result(env):
    result = env.evaluation_result_list[-1]
    print(f"[{env.iteration}] {result[1]}'s {result[0]}: {result[2]}")


params = {
    "boosting_type": "gbdt",
    "objective": "regression",
    "metric": "root_mean_squared_error",
    "max_depth": 7,
    "learning_rate": 0.02,
    "verbose": 0,
}
gbm = lgb.train(
    params,
    train_data,
    num_boost_round=15000,
    valid_sets=[test_data],
    callbacks=[print_validation_result],
)
# Out:
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=7) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=128) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=7) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=128) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=7) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=128) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [0] rmse's valid_0: 35.233859726434375
# [1] rmse's valid_0: 34.9695806237938
# [2] rmse's valid_0: 34.713957134265286
# [3] rmse's valid_0: 34.46517004549175
# [4] rmse's valid_0: 34.25471372319388
# [5] rmse's valid_0: 34.05100023752634
# [6] rmse's valid_0: 33.85464499945816
# [7] rmse's valid_0: 33.65590333620044
# [8] rmse's valid_0: 33.47372030611987
# [9] rmse's valid_0: 33.28339742057547
# [10] rmse's valid_0: 33.07509345190454
# [11] rmse's valid_0: 32.87578915447446
# [12] rmse's valid_0: 32.69992609900468
# [13] rmse's valid_0: 32.53811279469397
# [14] rmse's valid_0: 32.36980339338838
# [15] rmse's valid_0: 32.20959851269706
# [16] rmse's valid_0: 32.048191280658585
# [17] rmse's valid_0: 31.897155925335642
# [18] rmse's valid_0: 31.751417290772128
# [19] rmse's valid_0: 31.60643075251263
# [20] rmse's valid_0: 31.444918339785765
# [21] rmse's valid_0: 31.317856446736034
# [22] rmse's valid_0: 31.19017548566797
# [23] rmse's valid_0: 31.06719956832748
# [24] rmse's valid_0: 30.94993992960882
# [25] rmse's valid_0: 30.832944047483487
# [26] rmse's valid_0: 30.716185419504427
# [27] rmse's valid_0: 30.579722672558788
# [28] rmse's valid_0: 30.474405849452893
# [29] rmse's valid_0: 30.373444765013527
# [30] rmse's valid_0: 30.27285157545589
# [31] rmse's valid_0: 30.162446621132883
# [32] rmse's valid_0: 30.040378364762013
# [33] rmse's valid_0: 29.9487151238389
# [34] rmse's valid_0: 29.84713575042119
# [35] rmse's valid_0: 29.74629829575245
# [36] rmse's valid_0: 29.634732275828174
# [37] rmse's valid_0: 29.53858448526481
# [38] rmse's valid_0: 29.451372334766155
# [39] rmse's valid_0: 29.345710528216998
# [40] rmse's valid_0: 29.257531361758037
# [41] rmse's valid_0: 29.158892330130747
# [42] rmse's valid_0: 29.080570779447715
# [43] rmse's valid_0: 28.996478175421323
# [44] rmse's valid_0: 28.90381958151505
# [45] rmse's valid_0: 28.830006870259183
# [46] rmse's valid_0: 28.75486282556434
# [47] rmse's valid_0: 28.668765191687466
# [48] rmse's valid_0: 28.596927629833502
# [49] rmse's valid_0: 28.523130078652102
# [50] rmse's valid_0: 28.454767233389592
# [51] rmse's valid_0: 28.37684350927366
# [52] rmse's valid_0: 28.311798643085904
# [53] rmse's valid_0: 28.2370850271458
# [54] rmse's valid_0: 28.1764080728794
# [55] rmse's valid_0: 28.105212275010036
# [56] rmse's valid_0: 28.03760331536214
# [57] rmse's valid_0: 27.98041666476705
# [58] rmse's valid_0: 27.91572822584263
# [59] rmse's valid_0: 27.86277565358915
# [60] rmse's valid_0: 27.809748204014443
# [61] rmse's valid_0: 27.748521300575852
# [62] rmse's valid_0: 27.698668256996488
# [63] rmse's valid_0: 27.64018193851582
# [64] rmse's valid_0: 27.587956522727037
# [65] rmse's valid_0: 27.53370368785829
# [66] rmse's valid_0: 27.482547721117967
# [67] rmse's valid_0: 27.429845277557046
# [68] rmse's valid_0: 27.37674778671467
# [69] rmse's valid_0: 27.328580440187555
# [70] rmse's valid_0: 27.27807750264665
# [71] rmse's valid_0: 27.231828895006114
# [72] rmse's valid_0: 27.186841702970618
# [73] rmse's valid_0: 27.143427744696904
# [74] rmse's valid_0: 27.092011190762324
# [75] rmse's valid_0: 27.045010350069003
# [76] rmse's valid_0: 27.000489636391112
# [77] rmse's valid_0: 26.954944287398465
# [78] rmse's valid_0: 26.918088999407072
# [79] rmse's valid_0: 26.883539474795043
# [80] rmse's valid_0: 26.840589739304416
# [81] rmse's valid_0: 26.806330228195634
# [82] rmse's valid_0: 26.768042802020553
# [83] rmse's valid_0: 26.732678701755372
# [84] rmse's valid_0: 26.70166390892623
# [85] rmse's valid_0: 26.668827211310113
# [86] rmse's valid_0: 26.635786781171987
# [87] rmse's valid_0: 26.599899036329262
# [88] rmse's valid_0: 26.567826521724882
# [89] rmse's valid_0: 26.54063368625088
# [90] rmse's valid_0: 26.51395877939911
# [91] rmse's valid_0: 26.485616568882463
# [92] rmse's valid_0: 26.452614643238388
# [93] rmse's valid_0: 26.42706298512936
# [94] rmse's valid_0: 26.402058382831584
# [95] rmse's valid_0: 26.377691965171884
# [96] rmse's valid_0: 26.35389054044919
# [97] rmse's valid_0: 26.33366337540079
# [98] rmse's valid_0: 26.30726979373721
# [99] rmse's valid_0: 26.288242055470867
# [100] rmse's valid_0: 26.268438952438032
# [101] rmse's valid_0: 26.242187048833955
# [102] rmse's valid_0: 26.224065342953967
# [103] rmse's valid_0: 26.196995952601004
# [104] rmse's valid_0: 26.180000027827177
# [105] rmse's valid_0: 26.156614300881323
# [106] rmse's valid_0: 26.139231445991108
# [107] rmse's valid_0: 26.12360671370144
# [108] rmse's valid_0: 26.101995218384555
# [109] rmse's valid_0: 26.086309913683397
# [110] rmse's valid_0: 26.070178991046387
# [111] rmse's valid_0: 26.055837913369484
# [112] rmse's valid_0: 26.038019706462887
# [113] rmse's valid_0: 26.00544222449883
# [114] rmse's valid_0: 25.990819100759214
# [115] rmse's valid_0: 25.97601620438297
# [116] rmse's valid_0: 25.964503151410852
# [117] rmse's valid_0: 25.93102400399047
# [118] rmse's valid_0: 25.911937425798033
# [119] rmse's valid_0: 25.89993223718432
# [120] rmse's valid_0: 25.86588785411315
# [121] rmse's valid_0: 25.84953834995431
# [122] rmse's valid_0: 25.83532499170298
# [123] rmse's valid_0: 25.815381749102794
# [124] rmse's valid_0: 25.78411782091674
# [125] rmse's valid_0: 25.769181326604205
# [126] rmse's valid_0: 25.745571690381343
# [127] rmse's valid_0: 25.715868590679463
# [128] rmse's valid_0: 25.702159575166686
# [129] rmse's valid_0: 25.680834190574068
# [130] rmse's valid_0: 25.650088849961588
# [131] rmse's valid_0: 25.630221900452526
# [132] rmse's valid_0: 25.61773950000212
# [133] rmse's valid_0: 25.598150795880034
# [134] rmse's valid_0: 25.577513441218024
# [135] rmse's valid_0: 25.568339758771536
# [136] rmse's valid_0: 25.54667823223661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137] rmse's valid_0: 25.537494294782455
# [138] rmse's valid_0: 25.521621615361276
# [139] rmse's valid_0: 25.502973582028382
# [140] rmse's valid_0: 25.484938701072444
# [141] rmse's valid_0: 25.471465689450387
# [142] rmse's valid_0: 25.45653464164147
# [143] rmse's valid_0: 25.44254790500774
# [144] rmse's valid_0: 25.4260298582823
# [145] rmse's valid_0: 25.41266294002752
# [146] rmse's valid_0: 25.394181077732178
# [147] rmse's valid_0: 25.37905530446627
# [148] rmse's valid_0: 25.36499691335255
# [149] rmse's valid_0: 25.353466090985723
# [150] rmse's valid_0: 25.340178964952035
# [151] rmse's valid_0: 25.324995227775315
# [152] rmse's valid_0: 25.311678187902494
# [153] rmse's valid_0: 25.298176911700235
# [154] rmse's valid_0: 25.285248549339975
# [155] rmse's valid_0: 25.27465693253691
# [156] rmse's valid_0: 25.262322127427648
# [157] rmse's valid_0: 25.250593910088913
# [158] rmse's valid_0: 25.238161762383
# [159] rmse's valid_0: 25.226304469374277
# [160] rmse's valid_0: 25.218041499902508
# [161] rmse's valid_0: 25.205560389168884
# [162] rmse's valid_0: 25.194076102579857
# [163] rmse's valid_0: 25.184065084917336
# [164] rmse's valid_0: 25.172372607869114
# [165] rmse's valid_0: 25.15806711440837
# [166] rmse's valid_0: 25.149347156752235
# [167] rmse's valid_0: 25.138211524327485
# [168] rmse's valid_0: 25.131370828606432
# [169] rmse's valid_0: 25.11773200588295
# [170] rmse's valid_0: 25.10806629806703
# [171] rmse's valid_0: 25.100117019681075
# [172] rmse's valid_0: 25.079410217130743
# [173] rmse's valid_0: 25.072458726987865
# [174] rmse's valid_0: 25.066288565683877
# [175] rmse's valid_0: 25.058280269974837
# [176] rmse's valid_0: 25.047984366549848
# [177] rmse's valid_0: 25.036861732374625
# [178] rmse's valid_0: 25.023706661067447
# [179] rmse's valid_0: 25.015404996685064
# [180] rmse's valid_0: 25.005480147929788
# [181] rmse's valid_0: 24.993287176452068
# [182] rmse's valid_0: 24.9869897595925
# [183] rmse's valid_0: 24.976819391550467
# [184] rmse's valid_0: 24.964719437865828
# [185] rmse's valid_0: 24.95014794533962
# [186] rmse's valid_0: 24.937845689320653
# [187] rmse's valid_0: 24.928560199445954
# [188] rmse's valid_0: 24.918698889592918
# [189] rmse's valid_0: 24.911093286040387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190] rmse's valid_0: 24.905491550738038
# [191] rmse's valid_0: 24.892611117460756
# [192] rmse's valid_0: 24.887014954829198
# [193] rmse's valid_0: 24.87893481260194
# [194] rmse's valid_0: 24.873899044340476
# [195] rmse's valid_0: 24.860164326556554
# [196] rmse's valid_0: 24.851136641662766
# [197] rmse's valid_0: 24.84358322354284
# [198] rmse's valid_0: 24.838941621599343
# [199] rmse's valid_0: 24.831551662660207
# [200] rmse's valid_0: 24.820328470433658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201] rmse's valid_0: 24.81555773880442
# [202] rmse's valid_0: 24.802134054810924
# [203] rmse's valid_0: 24.79065623930638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204] rmse's valid_0: 24.78693215547696
# [205] rmse's valid_0: 24.78133265649184
# [206] rmse's valid_0: 24.773191897388887
# [207] rmse's valid_0: 24.760232730046827
# [208] rmse's valid_0: 24.7553729633075
# [209] rmse's valid_0: 24.749870496239755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210] rmse's valid_0: 24.746646523428318
# [211] rmse's valid_0: 24.741015153332178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212] rmse's valid_0: 24.73389751369663
# [213] rmse's valid_0: 24.721379225617753
# [214] rmse's valid_0: 24.716109459923345
# [215] rmse's valid_0: 24.71062463349766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216] rmse's valid_0: 24.70805492688742
# [217] rmse's valid_0: 24.697169108229552
# [218] rmse's valid_0: 24.689934173090393
# [219] rmse's valid_0: 24.678189037194237
# [220] rmse's valid_0: 24.670605117810197
# [221] rmse's valid_0: 24.665701463659886
# [222] rmse's valid_0: 24.658905248555
# [223] rmse's valid_0: 24.647413166534164
# [224] rmse's valid_0: 24.64094686242568
# [225] rmse's valid_0: 24.633960702515207
# [226] rmse's valid_0: 24.629563740444123
# [227] rmse's valid_0: 24.618938656834064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228] rmse's valid_0: 24.616452038941247
# [229] rmse's valid_0: 24.605550493436088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230] rmse's valid_0: 24.602982850606246
# [231] rmse's valid_0: 24.592888411627037
# [232] rmse's valid_0: 24.585438860763823
# [233] rmse's valid_0: 24.576107451899425
# [234] rmse's valid_0: 24.564402184183276
# [235] rmse's valid_0: 24.554398460072296
# [236] rmse's valid_0: 24.550181693905664
# [237] rmse's valid_0: 24.54496174546759
# [238] rmse's valid_0: 24.53942743968176
# [239] rmse's valid_0: 24.5323268339358
# [240] rmse's valid_0: 24.528198985945856
# [241] rmse's valid_0: 24.524928088694647
# [242] rmse's valid_0: 24.517475014735112
# [243] rmse's valid_0: 24.51289312205119
# [244] rmse's valid_0: 24.504126899999548
# [245] rmse's valid_0: 24.49931287925155
# [246] rmse's valid_0: 24.493151163876135
# [247] rmse's valid_0: 24.489059530404074
# [248] rmse's valid_0: 24.480164126136028
# [249] rmse's valid_0: 24.47632757915027
# [250] rmse's valid_0: 24.470697605715667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251] rmse's valid_0: 24.466394380541864
# [252] rmse's valid_0: 24.45649717214123
# [253] rmse's valid_0: 24.452023122644025
# [254] rmse's valid_0: 24.44336599136718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255] rmse's valid_0: 24.440132219676904
# [256] rmse's valid_0: 24.436546344008615
# [257] rmse's valid_0: 24.424628828432454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258] rmse's valid_0: 24.42245912389382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259] rmse's valid_0: 24.41180928939449
# [260] rmse's valid_0: 24.40406877194089
# [261] rmse's valid_0: 24.398818891949137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262] rmse's valid_0: 24.396677768490107
# [263] rmse's valid_0: 24.389998889478107
# [264] rmse's valid_0: 24.385613909608583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265] rmse's valid_0: 24.384004755437957
# [266] rmse's valid_0: 24.378196010560963
# [267] rmse's valid_0: 24.373666239473202
# [268] rmse's valid_0: 24.36397496421569
# [269] rmse's valid_0: 24.356364341694107
# [270] rmse's valid_0: 24.349831095741777
# [271] rmse's valid_0: 24.345045797703442
# [272] rmse's valid_0: 24.34029761624068
# [273] rmse's valid_0: 24.332448422535002
# [274] rmse's valid_0: 24.326255786970282
# [275] rmse's valid_0: 24.321767538518035
# [276] rmse's valid_0: 24.317803219082098
# [277] rmse's valid_0: 24.31263584433242
# [278] rmse's valid_0: 24.307415616767017
# [279] rmse's valid_0: 24.30256905117376
# [280] rmse's valid_0: 24.29419492895233
# [281] rmse's valid_0: 24.289728450287377
# [282] rmse's valid_0: 24.28609470863864
# [283] rmse's valid_0: 24.27527343357918
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284] rmse's valid_0: 24.273583817647573
# [285] rmse's valid_0: 24.26821585935783
# [286] rmse's valid_0: 24.263976978170334
# [287] rmse's valid_0: 24.25627682336054
# [288] rmse's valid_0: 24.245943547051688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289] rmse's valid_0: 24.242514068085008
# [290] rmse's valid_0: 24.237538286528782
# [291] rmse's valid_0: 24.23178265229932
# [292] rmse's valid_0: 24.228288762024665
# [293] rmse's valid_0: 24.225527530279614
# [294] rmse's valid_0: 24.22377336062229
# [295] rmse's valid_0: 24.220439974103694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296] rmse's valid_0: 24.21723003560831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297] rmse's valid_0: 24.21568482484599
# [298] rmse's valid_0: 24.21129320322238
# [299] rmse's valid_0: 24.2064103461264
# [300] rmse's valid_0: 24.19806560361949
# [301] rmse's valid_0: 24.192421282544565
# [302] rmse's valid_0: 24.18318090501124
# [303] rmse's valid_0: 24.178017742016916
# [304] rmse's valid_0: 24.17451452384758
# [305] rmse's valid_0: 24.166233728041316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306] rmse's valid_0: 24.160882818213405
# [307] rmse's valid_0: 24.154811707612463
# [308] rmse's valid_0: 24.149976636330823
# [309] rmse's valid_0: 24.147219920702085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310] rmse's valid_0: 24.144478233292347
# [311] rmse's valid_0: 24.136910432038185
# [312] rmse's valid_0: 24.133516325739357
# [313] rmse's valid_0: 24.130107043360766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314] rmse's valid_0: 24.128483033438084
# [315] rmse's valid_0: 24.124140898194682
# [316] rmse's valid_0: 24.117971975008324
# [317] rmse's valid_0: 24.111326769175555
# [318] rmse's valid_0: 24.107938061606973
# [319] rmse's valid_0: 24.101965313745666
# [320] rmse's valid_0: 24.099084660462395
# [321] rmse's valid_0: 24.09277260922054
# [322] rmse's valid_0: 24.087585812174783
# [323] rmse's valid_0: 24.083313757911835
# [324] rmse's valid_0: 24.07384115050674
# [325] rmse's valid_0: 24.069166690224154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326] rmse's valid_0: 24.065042167248144
# [327] rmse's valid_0: 24.058922464758375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328] rmse's valid_0: 24.057289076848168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329] rmse's valid_0: 24.054264643643748
# [330] rmse's valid_0: 24.049734408013954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331] rmse's valid_0: 24.045833396072354
# [332] rmse's valid_0: 24.04061795321172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333] rmse's valid_0: 24.037105664554073
# [334] rmse's valid_0: 24.030321260186327
# [335] rmse's valid_0: 24.022169656273224
# [336] rmse's valid_0: 24.01916652784806
# [337] rmse's valid_0: 24.01312174540261
# [338] rmse's valid_0: 24.005029958219854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339] rmse's valid_0: 24.000007785081422
# [340] rmse's valid_0: 23.993668276571334
# [341] rmse's valid_0: 23.986691089303683
# [342] rmse's valid_0: 23.98410834722767
# [343] rmse's valid_0: 23.978398047662917
# [344] rmse's valid_0: 23.975186561337843
# [345] rmse's valid_0: 23.97181759507705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346] rmse's valid_0: 23.968231892678467
# [347] rmse's valid_0: 23.965127983285498
# [348] rmse's valid_0: 23.961178586289794
# [349] rmse's valid_0: 23.95599451969423
# [350] rmse's valid_0: 23.95139673797659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351] rmse's valid_0: 23.946890779763343
# [352] rmse's valid_0: 23.943454960066767
# [353] rmse's valid_0: 23.9412691699618
# [354] rmse's valid_0: 23.936341256746584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355] rmse's valid_0: 23.934929305327252
# [356] rmse's valid_0: 23.92793945069508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357] rmse's valid_0: 23.924037858397906
# [358] rmse's valid_0: 23.91849892209826
# [359] rmse's valid_0: 23.915274807437278
# [360] rmse's valid_0: 23.910691614069936
# [361] rmse's valid_0: 23.907781242835902
# [362] rmse's valid_0: 23.902893427231962
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363] rmse's valid_0: 23.901615313167426
# [364] rmse's valid_0: 23.892144849236864
# [365] rmse's valid_0: 23.890522549202874
# [366] rmse's valid_0: 23.888252204945797
# [367] rmse's valid_0: 23.883099344999945
# [368] rmse's valid_0: 23.87805803774231
# [369] rmse's valid_0: 23.874331457180393
# [370] rmse's valid_0: 23.871053663958318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371] rmse's valid_0: 23.87010794274136
# [372] rmse's valid_0: 23.868437076586734
# [373] rmse's valid_0: 23.86352683300115
# [374] rmse's valid_0: 23.859300202498417
# [375] rmse's valid_0: 23.854527187815588
# [376] rmse's valid_0: 23.85275280389004
# [377] rmse's valid_0: 23.85048138950017
# [378] rmse's valid_0: 23.845962347192643
# [379] rmse's valid_0: 23.84172295767851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380] rmse's valid_0: 23.840617237353335
# [381] rmse's valid_0: 23.835723180110076
# [382] rmse's valid_0: 23.830651978857926
# [383] rmse's valid_0: 23.82624402779279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384] rmse's valid_0: 23.823954235350232
# [385] rmse's valid_0: 23.81881437532223
# [386] rmse's valid_0: 23.814484020732834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387] rmse's valid_0: 23.81180419241135
# [388] rmse's valid_0: 23.80697399697329
# [389] rmse's valid_0: 23.803634105281336
# [390] rmse's valid_0: 23.800676355794767
# [391] rmse's valid_0: 23.79435227602723
# [392] rmse's valid_0: 23.790154058790282
# [393] rmse's valid_0: 23.786758676655236
# [394] rmse's valid_0: 23.781738882438166
# [395] rmse's valid_0: 23.77826156966219
# [396] rmse's valid_0: 23.774378932999042
# [397] rmse's valid_0: 23.770970415855228
# [398] rmse's valid_0: 23.768302482134782
# [399] rmse's valid_0: 23.762225401154833
# [400] rmse's valid_0: 23.75640798706781
# [401] rmse's valid_0: 23.751258845390502
# [402] rmse's valid_0: 23.746451158646366
# [403] rmse's valid_0: 23.74279882745341
# [404] rmse's valid_0: 23.739391814013285
# [405] rmse's valid_0: 23.73697707559061
# [406] rmse's valid_0: 23.732745424329526
# [407] rmse's valid_0: 23.727226830773084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408] rmse's valid_0: 23.723903020924922
# [409] rmse's valid_0: 23.719722432612112
# [410] rmse's valid_0: 23.714993667162044
# [411] rmse's valid_0: 23.712224220614747
# [412] rmse's valid_0: 23.708568411894404
# [413] rmse's valid_0: 23.704690555562195
# [414] rmse's valid_0: 23.70038863653304
# [415] rmse's valid_0: 23.697629734155534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416] rmse's valid_0: 23.695630846176
# [417] rmse's valid_0: 23.692664784843732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418] rmse's valid_0: 23.69154631320473
# [419] rmse's valid_0: 23.689806414321794
# [420] rmse's valid_0: 23.6820141755499
# [421] rmse's valid_0: 23.67990059945955
# [422] rmse's valid_0: 23.678160363903835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423] rmse's valid_0: 23.674655501339114
# [424] rmse's valid_0: 23.6721939812392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425] rmse's valid_0: 23.671659419724428
# [426] rmse's valid_0: 23.669498514682036
# [427] rmse's valid_0: 23.66468346149234
# [428] rmse's valid_0: 23.663135892329883
# [429] rmse's valid_0: 23.662224005658484
# [430] rmse's valid_0: 23.659473492472546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431] rmse's valid_0: 23.657956055033413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [432] rmse's valid_0: 23.654275055012082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433] rmse's valid_0: 23.65178419343185
# [434] rmse's valid_0: 23.645512748022394
# [435] rmse's valid_0: 23.64365328577035
# [436] rmse's valid_0: 23.642079010608157
# [437] rmse's valid_0: 23.639582952178323
# [438] rmse's valid_0: 23.635453080308466
# [439] rmse's valid_0: 23.63372680442534
# [440] rmse's valid_0: 23.63082775735295
# [441] rmse's valid_0: 23.62502744986387
# [442] rmse's valid_0: 23.6226833602542
# [443] rmse's valid_0: 23.619897034704348
# [444] rmse's valid_0: 23.617622630338424
# [445] rmse's valid_0: 23.613685011374464
# [446] rmse's valid_0: 23.609674893152068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447] rmse's valid_0: 23.607323019532647
# [448] rmse's valid_0: 23.60001608865875
# [449] rmse's valid_0: 23.59881969440861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450] rmse's valid_0: 23.597413546879874
# [451] rmse's valid_0: 23.596307697918203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452] rmse's valid_0: 23.59467399169037
# [453] rmse's valid_0: 23.58827040265275
# [454] rmse's valid_0: 23.585113505945365
# [455] rmse's valid_0: 23.583002123384343
# [456] rmse's valid_0: 23.580010990568088
# [457] rmse's valid_0: 23.577775732875793
# [458] rmse's valid_0: 23.572634125998395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [459] rmse's valid_0: 23.571613761565246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460] rmse's valid_0: 23.569021874434213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [461] rmse's valid_0: 23.566083601361647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462] rmse's valid_0: 23.563868908974946
# [463] rmse's valid_0: 23.55859294388785
# [464] rmse's valid_0: 23.556938538740653
# [465] rmse's valid_0: 23.554866407727772
# [466] rmse's valid_0: 23.55112786826368
# [467] rmse's valid_0: 23.545895453981803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [468] rmse's valid_0: 23.544016148784788
# [469] rmse's valid_0: 23.542407352985474
# [470] rmse's valid_0: 23.537270918616915
# [471] rmse's valid_0: 23.531794147041296
# [472] rmse's valid_0: 23.524194245338446
# [473] rmse's valid_0: 23.51742318444189
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [474] rmse's valid_0: 23.514606577818913
# [475] rmse's valid_0: 23.510424438477507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [476] rmse's valid_0: 23.508263633240816
# [477] rmse's valid_0: 23.505036136672988
# [478] rmse's valid_0: 23.50426352437575
# [479] rmse's valid_0: 23.498850503230425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480] rmse's valid_0: 23.4977685571423
# [481] rmse's valid_0: 23.49678148961491
# [482] rmse's valid_0: 23.49511745850401
# [483] rmse's valid_0: 23.48731708274275
# [484] rmse's valid_0: 23.48436455187111
# [485] rmse's valid_0: 23.480747676332985
# [486] rmse's valid_0: 23.476667899974224
# [487] rmse's valid_0: 23.468239797149494
# [488] rmse's valid_0: 23.466144750656397
# [489] rmse's valid_0: 23.46205606419968
# [490] rmse's valid_0: 23.458591241549655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [491] rmse's valid_0: 23.454877057405792
# [492] rmse's valid_0: 23.453521923629136
# [493] rmse's valid_0: 23.450713446361714
# [494] rmse's valid_0: 23.449119487949176
# [495] rmse's valid_0: 23.444697994550808
# [496] rmse's valid_0: 23.43860650026918
# [497] rmse's valid_0: 23.43448786552585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498] rmse's valid_0: 23.430894667519187
# [499] rmse's valid_0: 23.428379797664988
# [500] rmse's valid_0: 23.425257213286002
# [501] rmse's valid_0: 23.424666545374304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502] rmse's valid_0: 23.42380503537771
# [503] rmse's valid_0: 23.421145190431023
# [504] rmse's valid_0: 23.41843844375361
# [505] rmse's valid_0: 23.41706659556015
# [506] rmse's valid_0: 23.410079643872784
# [507] rmse's valid_0: 23.407356353129266
# [508] rmse's valid_0: 23.400953612754986
# [509] rmse's valid_0: 23.396797277267506
# [510] rmse's valid_0: 23.3930013302282
# [511] rmse's valid_0: 23.390735054595844
# [512] rmse's valid_0: 23.388706395336293
# [513] rmse's valid_0: 23.386806408136415
# [514] rmse's valid_0: 23.38626521103379
# [515] rmse's valid_0: 23.38192053221036
# [516] rmse's valid_0: 23.37800777703006
# [517] rmse's valid_0: 23.376708105550854
# [518] rmse's valid_0: 23.374520621347475
# [519] rmse's valid_0: 23.370249462717027
# [520] rmse's valid_0: 23.366656278951126
# [521] rmse's valid_0: 23.364487479164815
# [522] rmse's valid_0: 23.363153171522228
# [523] rmse's valid_0: 23.360921868283416
# [524] rmse's valid_0: 23.357765529476872
# [525] rmse's valid_0: 23.35408694366483
# [526] rmse's valid_0: 23.351661546679747
# [527] rmse's valid_0: 23.348435866847232
# [528] rmse's valid_0: 23.347425312519107
# [529] rmse's valid_0: 23.34300951693864
# [530] rmse's valid_0: 23.341894720304165
# [531] rmse's valid_0: 23.3399046416282
# [532] rmse's valid_0: 23.338665765767374
# [533] rmse's valid_0: 23.33571929190107
# [534] rmse's valid_0: 23.332417678457524
# [535] rmse's valid_0: 23.330847455752565
# [536] rmse's valid_0: 23.326805289047442
# [537] rmse's valid_0: 23.32605010347977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [538] rmse's valid_0: 23.324132651675512
# [539] rmse's valid_0: 23.322772332393765
# [540] rmse's valid_0: 23.320626205090843
# [541] rmse's valid_0: 23.316741233788527
# [542] rmse's valid_0: 23.31545923418789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [543] rmse's valid_0: 23.31309805226741
# [544] rmse's valid_0: 23.308511895655936
# [545] rmse's valid_0: 23.303193585522063
# [546] rmse's valid_0: 23.301204989529015
# [547] rmse's valid_0: 23.299832376049917
# [548] rmse's valid_0: 23.29703341755242
# [549] rmse's valid_0: 23.293166034325786
# [550] rmse's valid_0: 23.289137968725022
# [551] rmse's valid_0: 23.284587631728325
# [552] rmse's valid_0: 23.28337882722246
# [553] rmse's valid_0: 23.28251066985805
# [554] rmse's valid_0: 23.277834931240562
# [555] rmse's valid_0: 23.27717226367013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [556] rmse's valid_0: 23.274264241335796
# [557] rmse's valid_0: 23.27236055213245
# [558] rmse's valid_0: 23.268430523093798
# [559] rmse's valid_0: 23.265459044537874
# [560] rmse's valid_0: 23.264193190528218
# [561] rmse's valid_0: 23.26337265965026
# [562] rmse's valid_0: 23.26203892536018
# [563] rmse's valid_0: 23.257625528318524
# [564] rmse's valid_0: 23.255209720030656
# [565] rmse's valid_0: 23.25130775307672
# [566] rmse's valid_0: 23.249488642962795
# [567] rmse's valid_0: 23.24855584546689
# [568] rmse's valid_0: 23.246538977447173
# [569] rmse's valid_0: 23.24621339285647
# [570] rmse's valid_0: 23.24206854829834
# [571] rmse's valid_0: 23.239225499578854
# [572] rmse's valid_0: 23.237967366788936
# [573] rmse's valid_0: 23.237299236358403
# [574] rmse's valid_0: 23.2355176229254
# [575] rmse's valid_0: 23.23131376439864
# [576] rmse's valid_0: 23.22993059079943
# [577] rmse's valid_0: 23.228463007115423
# [578] rmse's valid_0: 23.22537004220377
# [579] rmse's valid_0: 23.22094526932872
# [580] rmse's valid_0: 23.219143839512647
# [581] rmse's valid_0: 23.21791907002731
# [582] rmse's valid_0: 23.215346681539945
# [583] rmse's valid_0: 23.212398300091998
# [584] rmse's valid_0: 23.211499325093936
# [585] rmse's valid_0: 23.207703072031393
# [586] rmse's valid_0: 23.206879395420668
# [587] rmse's valid_0: 23.205035180410725
# [588] rmse's valid_0: 23.203935982198196
# [589] rmse's valid_0: 23.196073226894033
# [590] rmse's valid_0: 23.19335224322651
# [591] rmse's valid_0: 23.191694407322963
# [592] rmse's valid_0: 23.190626652595853
# [593] rmse's valid_0: 23.189319013270225
# [594] rmse's valid_0: 23.188344057262444
# [595] rmse's valid_0: 23.186301098013278
# [596] rmse's valid_0: 23.185685448095846
# [597] rmse's valid_0: 23.182027748222236
# [598] rmse's valid_0: 23.180272580600246
# [599] rmse's valid_0: 23.17770996110799
# [600] rmse's valid_0: 23.17529443078033
# [601] rmse's valid_0: 23.172945129271902
# [602] rmse's valid_0: 23.170789221101728
# [603] rmse's valid_0: 23.169206782805738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [604] rmse's valid_0: 23.166289494200935
# [605] rmse's valid_0: 23.165838221269038
# [606] rmse's valid_0: 23.161688270961843
# [607] rmse's valid_0: 23.155777983283457
# [608] rmse's valid_0: 23.152295016695415
# [609] rmse's valid_0: 23.1511581324587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [610] rmse's valid_0: 23.14863220975379
# [611] rmse's valid_0: 23.143426354854974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [612] rmse's valid_0: 23.140857600612822
# [613] rmse's valid_0: 23.138529939528578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614] rmse's valid_0: 23.135717663319763
# [615] rmse's valid_0: 23.132619708454573
# [616] rmse's valid_0: 23.129798370656694
# [617] rmse's valid_0: 23.12486875177725
# [618] rmse's valid_0: 23.123220036284607
# [619] rmse's valid_0: 23.119717993052568
# [620] rmse's valid_0: 23.114874768050328
# [621] rmse's valid_0: 23.113445258011378
# [622] rmse's valid_0: 23.111455549683622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [623] rmse's valid_0: 23.107612803572117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [624] rmse's valid_0: 23.105983939728315
# [625] rmse's valid_0: 23.101640368701165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [626] rmse's valid_0: 23.100357057656478
# [627] rmse's valid_0: 23.098545253329995
# [628] rmse's valid_0: 23.09534273762803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [629] rmse's valid_0: 23.092407875179983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [630] rmse's valid_0: 23.089352739813624
# [631] rmse's valid_0: 23.0844749765138
# [632] rmse's valid_0: 23.08294779880926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [633] rmse's valid_0: 23.081294843803267
# [634] rmse's valid_0: 23.07986236241528
# [635] rmse's valid_0: 23.07737549207645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [636] rmse's valid_0: 23.076263169648573
# [637] rmse's valid_0: 23.076008522545628
# [638] rmse's valid_0: 23.07508577327134
# [639] rmse's valid_0: 23.070513067827758
# [640] rmse's valid_0: 23.064470103940383
# [641] rmse's valid_0: 23.061090946986518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [642] rmse's valid_0: 23.05755908000152
# [643] rmse's valid_0: 23.05707589602618
# [644] rmse's valid_0: 23.05446129766839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [645] rmse's valid_0: 23.052209681182237
# [646] rmse's valid_0: 23.050546651057065
# [647] rmse's valid_0: 23.046843330431482
# [648] rmse's valid_0: 23.046321018347694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [649] rmse's valid_0: 23.044828938636726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [650] rmse's valid_0: 23.04335015523105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [651] rmse's valid_0: 23.040997214400377
# [652] rmse's valid_0: 23.039271713512278
# [653] rmse's valid_0: 23.035918648202983
# [654] rmse's valid_0: 23.03341014526488
# [655] rmse's valid_0: 23.029953614164697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [656] rmse's valid_0: 23.028663208333985
# [657] rmse's valid_0: 23.02536945450563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [658] rmse's valid_0: 23.0219621453349
# [659] rmse's valid_0: 23.019306347811327
# [660] rmse's valid_0: 23.018605593004946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [661] rmse's valid_0: 23.01552532800102
# [662] rmse's valid_0: 23.012894189839905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [663] rmse's valid_0: 23.01085181143968
# [664] rmse's valid_0: 23.009206590264647
# [665] rmse's valid_0: 23.00588740442571
# [666] rmse's valid_0: 23.004961521364425
# [667] rmse's valid_0: 23.004428997482584
# [668] rmse's valid_0: 23.00316172310795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [669] rmse's valid_0: 23.002718180861766
# [670] rmse's valid_0: 22.999798597725167
# [671] rmse's valid_0: 22.99671643825282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [672] rmse's valid_0: 22.993328913308005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [673] rmse's valid_0: 22.99124725987206
# [674] rmse's valid_0: 22.98887122201734
# [675] rmse's valid_0: 22.985849857768688
# [676] rmse's valid_0: 22.983456959128866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [677] rmse's valid_0: 22.982538992377922
# [678] rmse's valid_0: 22.98188281993995
# [679] rmse's valid_0: 22.978875374084723
# [680] rmse's valid_0: 22.975410529375328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [681] rmse's valid_0: 22.97358692708548
# [682] rmse's valid_0: 22.97299581484362
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [683] rmse's valid_0: 22.9727441098367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [684] rmse's valid_0: 22.970758982649095
# [685] rmse's valid_0: 22.967957828488057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [686] rmse's valid_0: 22.96682304428404
# [687] rmse's valid_0: 22.962206774154478
# [688] rmse's valid_0: 22.960532063475934
# [689] rmse's valid_0: 22.960018257606613
# [690] rmse's valid_0: 22.95876803113922
# [691] rmse's valid_0: 22.957010281162308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [692] rmse's valid_0: 22.955106041467097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [693] rmse's valid_0: 22.95159648284439
# [694] rmse's valid_0: 22.949806881252165
# [695] rmse's valid_0: 22.947840447934343
# [696] rmse's valid_0: 22.9448322874792
# [697] rmse's valid_0: 22.943205224277992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [698] rmse's valid_0: 22.942827420309992
# [699] rmse's valid_0: 22.94135713213164
# [700] rmse's valid_0: 22.94023296193235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [701] rmse's valid_0: 22.938548719177707
# [702] rmse's valid_0: 22.937329746385522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [703] rmse's valid_0: 22.934948711245784
# [704] rmse's valid_0: 22.93218514490182
# [705] rmse's valid_0: 22.93117215933937
# [706] rmse's valid_0: 22.928026721193582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [707] rmse's valid_0: 22.925781905830767
# [708] rmse's valid_0: 22.925055753509785
# [709] rmse's valid_0: 22.92311297020044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [710] rmse's valid_0: 22.922982828697243
# [711] rmse's valid_0: 22.920450675047604
# [712] rmse's valid_0: 22.917966958374123
# [713] rmse's valid_0: 22.916828395933024
# [714] rmse's valid_0: 22.915196765716473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [715] rmse's valid_0: 22.913421584198396
# [716] rmse's valid_0: 22.910143264232822
# [717] rmse's valid_0: 22.909144659083854
# [718] rmse's valid_0: 22.9068354893005
# [719] rmse's valid_0: 22.906010586663214
# [720] rmse's valid_0: 22.902917753951634
# [721] rmse's valid_0: 22.900239742990816
# [722] rmse's valid_0: 22.89779093287743
# [723] rmse's valid_0: 22.89726724109486
# [724] rmse's valid_0: 22.89326314739788
# [725] rmse's valid_0: 22.88929172152729
# [726] rmse's valid_0: 22.888373484013798
# [727] rmse's valid_0: 22.887589857889953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [728] rmse's valid_0: 22.887439532908438
# [729] rmse's valid_0: 22.88461047590042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [730] rmse's valid_0: 22.883965894760536
# [731] rmse's valid_0: 22.8812759413081
# [732] rmse's valid_0: 22.878801635314137
# [733] rmse's valid_0: 22.877084323602677
# [734] rmse's valid_0: 22.87450551360823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [735] rmse's valid_0: 22.874014453871876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [736] rmse's valid_0: 22.871027020989867
# [737] rmse's valid_0: 22.869564845823007
# [738] rmse's valid_0: 22.868380810029407
# [739] rmse's valid_0: 22.867254483965016
# [740] rmse's valid_0: 22.864779465653367
# [741] rmse's valid_0: 22.8635695752707
# [742] rmse's valid_0: 22.86052258233438
# [743] rmse's valid_0: 22.85944501383424
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [744] rmse's valid_0: 22.857981905793743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [745] rmse's valid_0: 22.85619954648087
# [746] rmse's valid_0: 22.85357869760718
# [747] rmse's valid_0: 22.85134463012637
# [748] rmse's valid_0: 22.84909937951741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [749] rmse's valid_0: 22.84751199500344
# [750] rmse's valid_0: 22.847046196097512
# [751] rmse's valid_0: 22.846334738117672
# [752] rmse's valid_0: 22.843942161811206
# [753] rmse's valid_0: 22.842303310996837
# [754] rmse's valid_0: 22.841208807297637
# [755] rmse's valid_0: 22.83968678410574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [756] rmse's valid_0: 22.83762545259848
# [757] rmse's valid_0: 22.835848967488477
# [758] rmse's valid_0: 22.83466713033428
# [759] rmse's valid_0: 22.832558121669013
# [760] rmse's valid_0: 22.832170560793287
# [761] rmse's valid_0: 22.82960139978779
# [762] rmse's valid_0: 22.828483032218053
# [763] rmse's valid_0: 22.82621459608042
# [764] rmse's valid_0: 22.823970504905386
# [765] rmse's valid_0: 22.822582385233684
# [766] rmse's valid_0: 22.821595125814827
# [767] rmse's valid_0: 22.820212622978065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [768] rmse's valid_0: 22.819480126090646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [769] rmse's valid_0: 22.816306609093807
# [770] rmse's valid_0: 22.814817070005677
# [771] rmse's valid_0: 22.812238131471943
# [772] rmse's valid_0: 22.810416279667457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [773] rmse's valid_0: 22.809081644756
# [774] rmse's valid_0: 22.80726137221724
# [775] rmse's valid_0: 22.80412993975746
# [776] rmse's valid_0: 22.80172156449094
# [777] rmse's valid_0: 22.799374855035175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [778] rmse's valid_0: 22.79768085169412
# [779] rmse's valid_0: 22.796769675461697
# [780] rmse's valid_0: 22.796003087412586
# [781] rmse's valid_0: 22.793590759864145
# [782] rmse's valid_0: 22.792400894615874
# [783] rmse's valid_0: 22.79059438245131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [784] rmse's valid_0: 22.790130688290198
# [785] rmse's valid_0: 22.787460916830344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [786] rmse's valid_0: 22.785998147083255
# [787] rmse's valid_0: 22.78355973852873
# [788] rmse's valid_0: 22.780894807736566
# [789] rmse's valid_0: 22.779045326685083
# [790] rmse's valid_0: 22.77813735275054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [791] rmse's valid_0: 22.7770182459236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [792] rmse's valid_0: 22.77435805555075
# [793] rmse's valid_0: 22.77218415667099
# [794] rmse's valid_0: 22.77129318878838
# [795] rmse's valid_0: 22.770288937898048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [796] rmse's valid_0: 22.767802304358376
# [797] rmse's valid_0: 22.766977097720215
# [798] rmse's valid_0: 22.765442909350853
# [799] rmse's valid_0: 22.76323841348052
# [800] rmse's valid_0: 22.761392213881653
# [801] rmse's valid_0: 22.760554924931697
# [802] rmse's valid_0: 22.75879790562943
# [803] rmse's valid_0: 22.757008564361044
# [804] rmse's valid_0: 22.75414924646725
# [805] rmse's valid_0: 22.753023798785023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [806] rmse's valid_0: 22.752337417442387
# [807] rmse's valid_0: 22.75121957980605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [808] rmse's valid_0: 22.75030122922038
# [809] rmse's valid_0: 22.748089616111045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [810] rmse's valid_0: 22.746587014464218
# [811] rmse's valid_0: 22.744680468417506
# [812] rmse's valid_0: 22.74348132940065
# [813] rmse's valid_0: 22.74235732919269
# [814] rmse's valid_0: 22.74092259842915
# [815] rmse's valid_0: 22.74016893218732
# [816] rmse's valid_0: 22.73887668962316
# [817] rmse's valid_0: 22.73642114050717
# [818] rmse's valid_0: 22.735301660101516
# [819] rmse's valid_0: 22.735273955500123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [820] rmse's valid_0: 22.734365934850864
# [821] rmse's valid_0: 22.732443562226546
# [822] rmse's valid_0: 22.73076467636776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [823] rmse's valid_0: 22.729409752501045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [824] rmse's valid_0: 22.728162103284642
# [825] rmse's valid_0: 22.72791775944557
# [826] rmse's valid_0: 22.724202252549233
# [827] rmse's valid_0: 22.72278109493637
# [828] rmse's valid_0: 22.721384369695315
# [829] rmse's valid_0: 22.721122600490535
# [830] rmse's valid_0: 22.720206626355054
# [831] rmse's valid_0: 22.717802726741795
# [832] rmse's valid_0: 22.715974002072592
# [833] rmse's valid_0: 22.712744440105816
# [834] rmse's valid_0: 22.71159564751547
# [835] rmse's valid_0: 22.71093245243038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [836] rmse's valid_0: 22.710685009132554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [837] rmse's valid_0: 22.710382226207326
# [838] rmse's valid_0: 22.70910563112875
# [839] rmse's valid_0: 22.706893766983672
# [840] rmse's valid_0: 22.704535545902488
# [841] rmse's valid_0: 22.703452617264553
# [842] rmse's valid_0: 22.70078407109164
# [843] rmse's valid_0: 22.699353484804053
# [844] rmse's valid_0: 22.697680627513478
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [845] rmse's valid_0: 22.695338270613412
# [846] rmse's valid_0: 22.69469269921724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [847] rmse's valid_0: 22.693872015241986
# [848] rmse's valid_0: 22.692595366740374
# [849] rmse's valid_0: 22.690759168872415
# [850] rmse's valid_0: 22.68866550505425
# [851] rmse's valid_0: 22.688020736927324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [852] rmse's valid_0: 22.686390484663583
# [853] rmse's valid_0: 22.684769403587566
# [854] rmse's valid_0: 22.684436676711506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [855] rmse's valid_0: 22.683456975675306
# [856] rmse's valid_0: 22.680214723427305
# [857] rmse's valid_0: 22.6796125165158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [858] rmse's valid_0: 22.678384648479447
# [859] rmse's valid_0: 22.675657385591137
# [860] rmse's valid_0: 22.675328960275714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [861] rmse's valid_0: 22.674323263205178
# [862] rmse's valid_0: 22.673145030886953
# [863] rmse's valid_0: 22.672686348915057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [864] rmse's valid_0: 22.671738687008684
# [865] rmse's valid_0: 22.670210505831232
# [866] rmse's valid_0: 22.669273034950248
# [867] rmse's valid_0: 22.667548963870782
# [868] rmse's valid_0: 22.667487338923877
# [869] rmse's valid_0: 22.666055464850174
# [870] rmse's valid_0: 22.665446815188808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [871] rmse's valid_0: 22.66454424078103
# [872] rmse's valid_0: 22.664092374835665
# [873] rmse's valid_0: 22.662531778145464
# [874] rmse's valid_0: 22.66165180473443
# [875] rmse's valid_0: 22.660177936055728
# [876] rmse's valid_0: 22.65933641386733
# [877] rmse's valid_0: 22.657646988380478
# [878] rmse's valid_0: 22.656667481398188
# [879] rmse's valid_0: 22.655827117018045
# [880] rmse's valid_0: 22.65332835012544
# [881] rmse's valid_0: 22.650548580622868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [882] rmse's valid_0: 22.648915465508875
# [883] rmse's valid_0: 22.646814906823845
# [884] rmse's valid_0: 22.645801458219808
# [885] rmse's valid_0: 22.645907469070988
# [886] rmse's valid_0: 22.642812174770345
# [887] rmse's valid_0: 22.64066448604666
# [888] rmse's valid_0: 22.638395444199542
# [889] rmse's valid_0: 22.636823440383328
# [890] rmse's valid_0: 22.634797971037536
# [891] rmse's valid_0: 22.634803025666844
# [892] rmse's valid_0: 22.63349693717395
# [893] rmse's valid_0: 22.63236426797768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [894] rmse's valid_0: 22.63203205884197
# [895] rmse's valid_0: 22.631115144615567
# [896] rmse's valid_0: 22.630567431996727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897] rmse's valid_0: 22.63001721122033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [898] rmse's valid_0: 22.628426194745824
# [899] rmse's valid_0: 22.62649128421882
# [900] rmse's valid_0: 22.625859189906954
# [901] rmse's valid_0: 22.62469413190446
# [902] rmse's valid_0: 22.62278405473509
# [903] rmse's valid_0: 22.621630966521764
# [904] rmse's valid_0: 22.620314640873712
# [905] rmse's valid_0: 22.61961934295522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [14725] rmse's valid_0: 20.51576219781844
# [14726] rmse's valid_0: 20.51567047417915
# [14727] rmse's valid_0: 20.515844112142837
# [14728] rmse's valid_0: 20.515633373341952
# [14729] rmse's valid_0: 20.515768943481927
# [14730] rmse's valid_0: 20.515917538874152
# [14731] rmse's valid_0: 20.5160311007671
# [14732] rmse's valid_0: 20.515628895639146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14733] rmse's valid_0: 20.51560696778071
# [14734] rmse's valid_0: 20.515491601996867
# [14735] rmse's valid_0: 20.51544706501426
# [14736] rmse's valid_0: 20.51542620863509
# [14737] rmse's valid_0: 20.515374246819288
# [14738] rmse's valid_0: 20.515261858394684
# [14739] rmse's valid_0: 20.515254784708315
# [14740] rmse's valid_0: 20.51520906903824
# [14741] rmse's valid_0: 20.51514305066242
# [14742] rmse's valid_0: 20.514836323999877
# [14743] rmse's valid_0: 20.51480399589602
# [14744] rmse's valid_0: 20.51475665379961
# [14745] rmse's valid_0: 20.514650420085168
# [14746] rmse's valid_0: 20.51454920581029
# [14747] rmse's valid_0: 20.514502601405727
# [14748] rmse's valid_0: 20.51466780267355
# [14749] rmse's valid_0: 20.5145355428182
# [14750] rmse's valid_0: 20.51445375097036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14751] rmse's valid_0: 20.514473222518408
# [14752] rmse's valid_0: 20.514487418585485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14753] rmse's valid_0: 20.51442839739876
# [14754] rmse's valid_0: 20.51444099801398
# [14755] rmse's valid_0: 20.514285231347262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14756] rmse's valid_0: 20.514243561124708
# [14757] rmse's valid_0: 20.514194694547495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14758] rmse's valid_0: 20.514184353488698
# [14759] rmse's valid_0: 20.514344987639742
# [14760] rmse's valid_0: 20.514368565211527
# [14761] rmse's valid_0: 20.514264287298612
# [14762] rmse's valid_0: 20.514227897822995
# [14763] rmse's valid_0: 20.514302397930223
# [14764] rmse's valid_0: 20.514282080639024
# [14765] rmse's valid_0: 20.514454724147473
# [14766] rmse's valid_0: 20.514056060206677
# [14767] rmse's valid_0: 20.51430087370855
# [14768] rmse's valid_0: 20.51414359960623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14769] rmse's valid_0: 20.514237462961802
# [14770] rmse's valid_0: 20.51422576425604
# [14771] rmse's valid_0: 20.514135960099544
# [14772] rmse's valid_0: 20.51400121073728
# [14773] rmse's valid_0: 20.513864858970713
# [14774] rmse's valid_0: 20.513617497256895
# [14775] rmse's valid_0: 20.51350625190828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14776] rmse's valid_0: 20.513637331173943
# [14777] rmse's valid_0: 20.513481706613156
# [14778] rmse's valid_0: 20.513411567815776
# [14779] rmse's valid_0: 20.513463265377332
# [14780] rmse's valid_0: 20.513047860718466
# [14781] rmse's valid_0: 20.51291211877143
# [14782] rmse's valid_0: 20.512772283968523
# [14783] rmse's valid_0: 20.51262884208406
# [14784] rmse's valid_0: 20.512423715775693
# [14785] rmse's valid_0: 20.51238488036965
# [14786] rmse's valid_0: 20.512270073075605
# [14787] rmse's valid_0: 20.512191723645444
# [14788] rmse's valid_0: 20.51218964875394
# [14789] rmse's valid_0: 20.512096166498814
# [14790] rmse's valid_0: 20.512046746835612
# [14791] rmse's valid_0: 20.511678981229903
# [14792] rmse's valid_0: 20.5116676332448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14793] rmse's valid_0: 20.511603226360013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14794] rmse's valid_0: 20.511534974326604
# [14795] rmse's valid_0: 20.511518105731437
# [14796] rmse's valid_0: 20.511136612045636
# [14797] rmse's valid_0: 20.51174205395352
# [14798] rmse's valid_0: 20.51180485572758
# [14799] rmse's valid_0: 20.51161503019382
# [14800] rmse's valid_0: 20.511656245467726
# [14801] rmse's valid_0: 20.51169325595645
# [14802] rmse's valid_0: 20.511752256746266
# [14803] rmse's valid_0: 20.51165126456664
# [14804] rmse's valid_0: 20.51138196905025
# [14805] rmse's valid_0: 20.51137298781788
# [14806] rmse's valid_0: 20.511239799326145
# [14807] rmse's valid_0: 20.511206733887793
# [14808] rmse's valid_0: 20.51126906421448
# [14809] rmse's valid_0: 20.511217567648448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14810] rmse's valid_0: 20.511131927613384
# [14811] rmse's valid_0: 20.511142192484645
# [14812] rmse's valid_0: 20.511280470113377
# [14813] rmse's valid_0: 20.511347516639322
# [14814] rmse's valid_0: 20.511326712806774
# [14815] rmse's valid_0: 20.511322888239757
# [14816] rmse's valid_0: 20.51130532345298
# [14817] rmse's valid_0: 20.51134509812385
# [14818] rmse's valid_0: 20.51132417745691
# [14819] rmse's valid_0: 20.511349309562114
# [14820] rmse's valid_0: 20.511310485441143
# [14821] rmse's valid_0: 20.51123856868069
# [14822] rmse's valid_0: 20.51129526227099
# [14823] rmse's valid_0: 20.511212268847746
# [14824] rmse's valid_0: 20.5111997612299
# [14825] rmse's valid_0: 20.51128019144059
# [14826] rmse's valid_0: 20.511265120098347
# [14827] rmse's valid_0: 20.511293245366026
# [14828] rmse's valid_0: 20.51116387847608
# [14829] rmse's valid_0: 20.511116223056696
# [14830] rmse's valid_0: 20.511103840748124
# [14831] rmse's valid_0: 20.511034570876003
# [14832] rmse's valid_0: 20.510989019164192
# [14833] rmse's valid_0: 20.51094094437806
# [14834] rmse's valid_0: 20.510930635048698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14835] rmse's valid_0: 20.510811697808325
# [14836] rmse's valid_0: 20.5108137901164
# [14837] rmse's valid_0: 20.51079876891234
# [14838] rmse's valid_0: 20.510735044319443
# [14839] rmse's valid_0: 20.510772291459215
# [14840] rmse's valid_0: 20.510762833407593
# [14841] rmse's valid_0: 20.51117906443034
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14842] rmse's valid_0: 20.511243342295142
# [14843] rmse's valid_0: 20.511261649676932
# [14844] rmse's valid_0: 20.511146399187744
# [14845] rmse's valid_0: 20.511067108329474
# [14846] rmse's valid_0: 20.510923051192876
# [14847] rmse's valid_0: 20.51062111478106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14848] rmse's valid_0: 20.510533132464246
# [14849] rmse's valid_0: 20.51053957873804
# [14850] rmse's valid_0: 20.51053799204321
# [14851] rmse's valid_0: 20.51041914080556
# [14852] rmse's valid_0: 20.510401014416043
# [14853] rmse's valid_0: 20.510394318711207
# [14854] rmse's valid_0: 20.510333456537733
# [14855] rmse's valid_0: 20.510317733880118
# [14856] rmse's valid_0: 20.5103988863159
# [14857] rmse's valid_0: 20.510380593878487
# [14858] rmse's valid_0: 20.51030796790469
# [14859] rmse's valid_0: 20.5102829326463
# [14860] rmse's valid_0: 20.510084340902548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14861] rmse's valid_0: 20.50999699312012
# [14862] rmse's valid_0: 20.509978175257018
# [14863] rmse's valid_0: 20.510353044319544
# [14864] rmse's valid_0: 20.51028421818953
# [14865] rmse's valid_0: 20.510274562304016
# [14866] rmse's valid_0: 20.509955531464435
# [14867] rmse's valid_0: 20.50967991263969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14868] rmse's valid_0: 20.50964758682285
# [14869] rmse's valid_0: 20.509470203683772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14870] rmse's valid_0: 20.50941965197027
# [14871] rmse's valid_0: 20.509155404849274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14872] rmse's valid_0: 20.509091711541465
# [14873] rmse's valid_0: 20.509069055184835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14874] rmse's valid_0: 20.509118080594906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14875] rmse's valid_0: 20.50914539227149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14876] rmse's valid_0: 20.509308302821957
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14877] rmse's valid_0: 20.50926780611003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14878] rmse's valid_0: 20.509343298660742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14879] rmse's valid_0: 20.509418722531166
# [14880] rmse's valid_0: 20.509410227217966
# [14881] rmse's valid_0: 20.509432072158926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14882] rmse's valid_0: 20.50942120875332
# [14883] rmse's valid_0: 20.509396768094906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14884] rmse's valid_0: 20.509466997185797
# [14885] rmse's valid_0: 20.509567587119033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14886] rmse's valid_0: 20.509606656332963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14887] rmse's valid_0: 20.50965424634042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14888] rmse's valid_0: 20.50974674658926
# [14889] rmse's valid_0: 20.50970671646667
# [14890] rmse's valid_0: 20.50967238424566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14891] rmse's valid_0: 20.50975644786128
# [14892] rmse's valid_0: 20.509809481840552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14893] rmse's valid_0: 20.510046523778897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14894] rmse's valid_0: 20.510104583160764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14895] rmse's valid_0: 20.510106177108682
# [14896] rmse's valid_0: 20.510094778252377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14897] rmse's valid_0: 20.510087169923867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14898] rmse's valid_0: 20.510281962899743
# [14899] rmse's valid_0: 20.509966532079982
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14900] rmse's valid_0: 20.510037098001586
# [14901] rmse's valid_0: 20.50990312338496
# [14902] rmse's valid_0: 20.509339371148215
# [14903] rmse's valid_0: 20.509153655021112
# [14904] rmse's valid_0: 20.509160402825856
# [14905] rmse's valid_0: 20.509160661924014
# [14906] rmse's valid_0: 20.508965151614863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14907] rmse's valid_0: 20.50891423632776
# [14908] rmse's valid_0: 20.50892285751962
# [14909] rmse's valid_0: 20.509244750619438
# [14910] rmse's valid_0: 20.509416261853772
# [14911] rmse's valid_0: 20.509390100290517
# [14912] rmse's valid_0: 20.50947024810801
# [14913] rmse's valid_0: 20.509507824216993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14914] rmse's valid_0: 20.509593880578343
# [14915] rmse's valid_0: 20.509686161063993
# [14916] rmse's valid_0: 20.509603662267104
# [14917] rmse's valid_0: 20.50945211995994
# [14918] rmse's valid_0: 20.509083260078764
# [14919] rmse's valid_0: 20.509009952793733
# [14920] rmse's valid_0: 20.50872654736142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14921] rmse's valid_0: 20.508974564806284
# [14922] rmse's valid_0: 20.508925834933827
# [14923] rmse's valid_0: 20.50876238928384
# [14924] rmse's valid_0: 20.508898807700056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14925] rmse's valid_0: 20.50869002552682
# [14926] rmse's valid_0: 20.508655971796443
# [14927] rmse's valid_0: 20.50843408162224
# [14928] rmse's valid_0: 20.508396673376012
# [14929] rmse's valid_0: 20.50856930207313
# [14930] rmse's valid_0: 20.508488036905252
# [14931] rmse's valid_0: 20.50816081187797
# [14932] rmse's valid_0: 20.508337048910334
# [14933] rmse's valid_0: 20.508291563730705
# [14934] rmse's valid_0: 20.508397057995797
# [14935] rmse's valid_0: 20.508357081397804
# [14936] rmse's valid_0: 20.50817931735312
# [14937] rmse's valid_0: 20.507770554512522
# [14938] rmse's valid_0: 20.50782093066225
# [14939] rmse's valid_0: 20.507480493736605
# [14940] rmse's valid_0: 20.507502799996747
# [14941] rmse's valid_0: 20.507299355739733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14942] rmse's valid_0: 20.50717862080917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14943] rmse's valid_0: 20.507198780204668
# [14944] rmse's valid_0: 20.50703319349118
# [14945] rmse's valid_0: 20.507214139958865
# [14946] rmse's valid_0: 20.507056355061515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14947] rmse's valid_0: 20.50706733429927
# [14948] rmse's valid_0: 20.5070785460384
# [14949] rmse's valid_0: 20.506955441877203
# [14950] rmse's valid_0: 20.506887639429745
# [14951] rmse's valid_0: 20.506835555446518
# [14952] rmse's valid_0: 20.506722618680577
# [14953] rmse's valid_0: 20.506650878707696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14954] rmse's valid_0: 20.506583909101693
# [14955] rmse's valid_0: 20.506463455131993
# [14956] rmse's valid_0: 20.506552359452165
# [14957] rmse's valid_0: 20.506492812698227
# [14958] rmse's valid_0: 20.506476270466187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14959] rmse's valid_0: 20.506427423421933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14960] rmse's valid_0: 20.506338039782264
# [14961] rmse's valid_0: 20.506246497781813
# [14962] rmse's valid_0: 20.506290974091907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14963] rmse's valid_0: 20.506205515058657
# [14964] rmse's valid_0: 20.50621193234923
# [14965] rmse's valid_0: 20.506245190780167
# [14966] rmse's valid_0: 20.506540088573033
# [14967] rmse's valid_0: 20.50655969936391
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14968] rmse's valid_0: 20.506477804217827
# [14969] rmse's valid_0: 20.50659792736392
# [14970] rmse's valid_0: 20.50661306684983
# [14971] rmse's valid_0: 20.506671276861642
# [14972] rmse's valid_0: 20.506651273497628
# [14973] rmse's valid_0: 20.506664545084565
# [14974] rmse's valid_0: 20.50657218432329
# [14975] rmse's valid_0: 20.50670440237457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14976] rmse's valid_0: 20.50669945754852
# [14977] rmse's valid_0: 20.506651582339867
# [14978] rmse's valid_0: 20.5065914878888
# [14979] rmse's valid_0: 20.506484424133653
# [14980] rmse's valid_0: 20.506273612637845
# [14981] rmse's valid_0: 20.506222224756605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14982] rmse's valid_0: 20.506238836601884
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14983] rmse's valid_0: 20.506202968183196
# [14984] rmse's valid_0: 20.50615408045324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14985] rmse's valid_0: 20.506146494627853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14986] rmse's valid_0: 20.506252515961343
# [14987] rmse's valid_0: 20.506320079423183
# [14988] rmse's valid_0: 20.506140976569284
# [14989] rmse's valid_0: 20.506081303215424
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14990] rmse's valid_0: 20.50605899821329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14991] rmse's valid_0: 20.50614443854417
# [14992] rmse's valid_0: 20.506087728240807
# [14993] rmse's valid_0: 20.506026376890645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14994] rmse's valid_0: 20.505853283500688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14995] rmse's valid_0: 20.50567130010651
# [14996] rmse's valid_0: 20.505710100144224
# [14997] rmse's valid_0: 20.505966286459156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14998] rmse's valid_0: 20.505762530397423
# [14999] rmse's valid_0: 20.505682685918636

# %%
y_pred = gbm.predict(feats.iloc[n_original:, :-1])

# %%
df_submit["mRNA_remaining_pct"] = y_pred
df_submit.to_csv("submission.csv", index=False)
