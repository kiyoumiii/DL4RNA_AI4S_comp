# %%
import pandas as pd

# %%
df_original = pd.read_csv("data/train_data.csv")
n_original = df_original.shape[0]
df_submit = pd.read_csv("data/sample_submission.csv")
df = pd.concat([df_original, df_submit], axis=0).reset_index(drop=True)

# %%
def siRNA_feat_builder(s: pd.Series, anti: bool = False):
    name = "anti" if anti else "sense"
    df = s.to_frame()
    df[f"feat_siRNA_{name}_seq_len"] = s.str.len()
    for pos in [0, -1]:
        for c in list("AUGC"):
            df[f"feat_siRNA_{name}_seq_{c}_{'front' if pos == 0 else 'back'}"] = (
                s.str[pos] == c
            )
    df[f"feat_siRNA_{name}_seq_pattern_1"] = s.str.startswith("AA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_2"] = s.str.startswith("GA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_3"] = s.str.startswith("CA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_4"] = s.str.startswith("UA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_5"] = s.str.startswith("UU") & s.str.endswith(
        "AA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_6"] = s.str.startswith("UU") & s.str.endswith(
        "GA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_7"] = s.str.startswith("UU") & s.str.endswith(
        "CA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_8"] = s.str.startswith("UU") & s.str.endswith(
        "UA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_9"] = s.str[1] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_10"] = s.str[-2] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_GC_frac"] = (
        s.str.contains("G") + s.str.contains("C")
    ) / s.str.len()
    return df.iloc[:, 1:]

# %%
df_publication_id = pd.get_dummies(df.publication_id)
df_publication_id.columns = [
    f"feat_publication_id_{c}" for c in df_publication_id.columns
]
df_gene_target_symbol_name = pd.get_dummies(df.gene_target_symbol_name)
df_gene_target_symbol_name.columns = [
    f"feat_gene_target_symbol_name_{c}" for c in df_gene_target_symbol_name.columns
]
df_gene_target_ncbi_id = pd.get_dummies(df.gene_target_ncbi_id)
df_gene_target_ncbi_id.columns = [
    f"feat_gene_target_ncbi_id_{c}" for c in df_gene_target_ncbi_id.columns
]
df_gene_target_species = pd.get_dummies(df.gene_target_species)
df_gene_target_species.columns = [
    f"feat_gene_target_species_{c}" for c in df_gene_target_species.columns
]
siRNA_duplex_id_values = df.siRNA_duplex_id.str.split("-|\.").str[1].astype("int")
siRNA_duplex_id_values = (siRNA_duplex_id_values - siRNA_duplex_id_values.min()) / (
    siRNA_duplex_id_values.max() - siRNA_duplex_id_values.min()
)
df_siRNA_duplex_id = pd.DataFrame(siRNA_duplex_id_values)
df_cell_line_donor = pd.get_dummies(df.cell_line_donor)
df_cell_line_donor.columns = [
    f"feat_cell_line_donor_{c}" for c in df_cell_line_donor.columns
]
df_cell_line_donor["feat_cell_line_donor_hepatocytes"] = (
    (df.cell_line_donor.str.contains("Hepatocytes")).fillna(False).astype("int")
)
df_cell_line_donor["feat_cell_line_donor_cells"] = (
    df.cell_line_donor.str.contains("Cells").fillna(False).astype("int")
)
df_siRNA_concentration = df.siRNA_concentration.to_frame()
df_Transfection_method = pd.get_dummies(df.Transfection_method)
df_Transfection_method.columns = [
    f"feat_Transfection_method_{c}" for c in df_Transfection_method.columns
]
df_Duration_after_transfection_h = pd.get_dummies(df.Duration_after_transfection_h)
df_Duration_after_transfection_h.columns = [
    f"feat_Duration_after_transfection_h_{c}"
    for c in df_Duration_after_transfection_h.columns
]
feats = pd.concat(
    [
        df_publication_id,
        df_gene_target_symbol_name,
        df_gene_target_ncbi_id,
        df_gene_target_species,
        df_siRNA_duplex_id,
        df_cell_line_donor,
        df_siRNA_concentration,
        df_Transfection_method,
        df_Duration_after_transfection_h,
        siRNA_feat_builder(df.siRNA_sense_seq, False),
        siRNA_feat_builder(df.siRNA_antisense_seq, True),
        df.iloc[:, -1].to_frame(),
    ],
    axis=1,
)

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split, KFold
import numpy as np
from sklearn.metrics import mean_absolute_error


X_train, X_test, y_train, y_test = train_test_split(
    feats.iloc[:n_original, :-1],
    feats.iloc[:n_original, -1],
    test_size=0.2,
    random_state=42,
)

# %%
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# 自定义评价函数
def calculate_metrics(preds, data, threshold=30):
    y_pred = preds
    y_true = data.get_label()
    mae = np.mean(np.abs(y_true - y_pred))
    
    y_true_binary = ((y_true <= threshold) & (y_true >= 0)).astype(int)
    y_pred_binary = ((y_pred <= threshold) & (y_pred >= 0)).astype(int)

    mask = (y_pred >= 0) & (y_pred <= threshold)
    range_mae = mean_absolute_error(y_true[mask], y_pred[mask]) if np.sum(mask) > 0 else 100

    precision = (np.array(y_pred_binary) & y_true_binary).sum() / np.sum(y_pred_binary) if np.sum(y_pred_binary) > 0 else 0
    recall = (np.array(y_pred_binary) & y_true_binary).sum() / np.sum(y_true_binary) if np.sum(y_true_binary) > 0 else 0

    if precision + recall == 0:
        f1 = 0
    else:
        f1 = 2 * precision * recall / (precision + recall)
    
    score = (1 - mae / 100) * 0.5 + (1 - range_mae / 100) * f1 * 0.5
    return "custom_score", score, True

# 自适应学习率回调函数
def adaptive_learning_rate(decay_rate=0.8, patience=50):
    best_score = float("-inf")
    wait = 0

    def callback(env):
        nonlocal best_score, wait
        current_score = env.evaluation_result_list[-1][2]
        current_lr = env.model.params.get('learning_rate')

        if current_score > best_score:
            best_score = current_score
            wait = 0
        else:
            wait += 1

        if wait >= patience:
            new_lr = float(current_lr) * decay_rate
            wait = 0
            env.model.params['learning_rate'] = new_lr
            print(f"Learning rate adjusted to {env.model.params.get('learning_rate')}")

    return callback

# 训练函数
def train(feats, n_original):
    n_splits = 10
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    gbms = []
    for fold, (train_idx, val_idx) in enumerate(kf.split(feats.iloc[:n_original, :]), 1):
        print(f"Starting fold {fold}")
        X_train, X_val = feats.iloc[train_idx, :-1], feats.iloc[val_idx, :-1]
        y_train, y_val = feats.iloc[train_idx, -1], feats.iloc[val_idx, -1]

        train_data = lgb.Dataset(X_train, label=y_train)
        val_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

        params = {
            "boosting_type": "gbdt",
            "objective": "regression",
            "metric": "None",
            "max_depth": 8,
            "num_leaves": 63,
            "min_data_in_leaf": 2,
            "learning_rate": 0.05,
            "feature_fraction": 0.9,
            "lambda_l1": 0.1,
            "lambda_l2": 0.2,
            "verbose": -1,
            "num_threads": 8,
        }

        adaptive_lr = adaptive_learning_rate(decay_rate=0.9, patience=1000)
        gbm = lgb.train(
            params,
            train_data,
            num_boost_round=25000,
            valid_sets=[val_data],
            feval=calculate_metrics,
            callbacks=[
                adaptive_lr,
                lgb.log_evaluation(period=200, show_stdv=True),
                lgb.early_stopping(stopping_rounds=int(25000*0.1), first_metric_only=True, verbose=True, min_delta=0.00001)
            ]
        )
        valid_score = gbm.best_score["valid_0"]["custom_score"]
        print(f"Fold {fold} best valid score: {valid_score}")
        gbms.append(gbm)

    return gbms

# 进行模型训练
trained_gbms = train(feats, n_original)
# Out:
# Starting fold 1
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.67566
# [400]	valid_0's custom_score: 0.701628
# [600]	valid_0's custom_score: 0.716475
# [800]	valid_0's custom_score: 0.72411
# [1000]	valid_0's custom_score: 0.734489
# [1200]	valid_0's custom_score: 0.740266
# [1400]	valid_0's custom_score: 0.740184
# [1600]	valid_0's custom_score: 0.744104
# [1800]	valid_0's custom_score: 0.747873
# [2000]	valid_0's custom_score: 0.752416
# [2200]	valid_0's custom_score: 0.755457
# [2400]	valid_0's custom_score: 0.756942
# [2600]	valid_0's custom_score: 0.760264
# [2800]	valid_0's custom_score: 0.760151
# [3000]	valid_0's custom_score: 0.762888
# [3200]	valid_0's custom_score: 0.76341
# [3400]	valid_0's custom_score: 0.764447
# [3600]	valid_0's custom_score: 0.765044
# [3800]	valid_0's custom_score: 0.764911
# [4000]	valid_0's custom_score: 0.765531
# [4200]	valid_0's custom_score: 0.762999
# [4400]	valid_0's custom_score: 0.763501
# [4600]	valid_0's custom_score: 0.764493
# Learning rate adjusted to 0.045000000000000005
# [4800]	valid_0's custom_score: 0.763054
# [5000]	valid_0's custom_score: 0.762062
# [5200]	valid_0's custom_score: 0.761159
# [5400]	valid_0's custom_score: 0.763059
# [5600]	valid_0's custom_score: 0.762484
# Learning rate adjusted to 0.04050000000000001
# [5800]	valid_0's custom_score: 0.762299
# [6000]	valid_0's custom_score: 0.759698
# [6200]	valid_0's custom_score: 0.76007
# Early stopping, best iteration is:
# [3710]	valid_0's custom_score: 0.766616
# Evaluated only: custom_score
# Fold 1 best valid score: 0.7666160191150813
# Starting fold 2
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.706433
# [400]	valid_0's custom_score: 0.736653
# [600]	valid_0's custom_score: 0.752683
# [800]	valid_0's custom_score: 0.764191
# [1000]	valid_0's custom_score: 0.767592
# [1200]	valid_0's custom_score: 0.77232
# [1400]	valid_0's custom_score: 0.774332
# [1600]	valid_0's custom_score: 0.777332
# [1800]	valid_0's custom_score: 0.778408
# [2000]	valid_0's custom_score: 0.779113
# [2200]	valid_0's custom_score: 0.780942
# [2400]	valid_0's custom_score: 0.782057
# [2600]	valid_0's custom_score: 0.782462
# [2800]	valid_0's custom_score: 0.784247
# [3000]	valid_0's custom_score: 0.783398
# [3200]	valid_0's custom_score: 0.784211
# [3400]	valid_0's custom_score: 0.784804
# [3600]	valid_0's custom_score: 0.784267
# [3800]	valid_0's custom_score: 0.784983
# [4000]	valid_0's custom_score: 0.784675
# [4200]	valid_0's custom_score: 0.78828
# [4400]	valid_0's custom_score: 0.786235
# [4600]	valid_0's custom_score: 0.785834
# [4800]	valid_0's custom_score: 0.787128
# [5000]	valid_0's custom_score: 0.787926
# [5200]	valid_0's custom_score: 0.786379
# [5400]	valid_0's custom_score: 0.788996
# [5600]	valid_0's custom_score: 0.788603
# [5800]	valid_0's custom_score: 0.787637
# [6000]	valid_0's custom_score: 0.789945
# [6200]	valid_0's custom_score: 0.788134
# [6400]	valid_0's custom_score: 0.788974
# [6600]	valid_0's custom_score: 0.788262
# [6800]	valid_0's custom_score: 0.788495
# [7000]	valid_0's custom_score: 0.787405
# Learning rate adjusted to 0.045000000000000005
# [7200]	valid_0's custom_score: 0.787175
# [7400]	valid_0's custom_score: 0.786849
# [7600]	valid_0's custom_score: 0.787741
# [7800]	valid_0's custom_score: 0.787584
# [8000]	valid_0's custom_score: 0.786939
# Learning rate adjusted to 0.04050000000000001
# [8200]	valid_0's custom_score: 0.787883
# [8400]	valid_0's custom_score: 0.787972
# Early stopping, best iteration is:
# [6015]	valid_0's custom_score: 0.790742
# Evaluated only: custom_score
# Fold 2 best valid score: 0.790742267533389
# Starting fold 3
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.691593
# [400]	valid_0's custom_score: 0.712652
# [600]	valid_0's custom_score: 0.728681
# [800]	valid_0's custom_score: 0.735231
# [1000]	valid_0's custom_score: 0.743405
# [1200]	valid_0's custom_score: 0.748736
# [1400]	valid_0's custom_score: 0.753687
# [1600]	valid_0's custom_score: 0.759514
# [1800]	valid_0's custom_score: 0.760452
# [2000]	valid_0's custom_score: 0.762449
# [2200]	valid_0's custom_score: 0.763444
# [2400]	valid_0's custom_score: 0.765243
# [2600]	valid_0's custom_score: 0.767844
# [2800]	valid_0's custom_score: 0.770036
# [3000]	valid_0's custom_score: 0.770523
# [3200]	valid_0's custom_score: 0.770857
# [3400]	valid_0's custom_score: 0.77186
# [3600]	valid_0's custom_score: 0.773663
# [3800]	valid_0's custom_score: 0.773544
# [4000]	valid_0's custom_score: 0.774353
# [4200]	valid_0's custom_score: 0.774685
# [4400]	valid_0's custom_score: 0.777211
# [4600]	valid_0's custom_score: 0.77816
# [4800]	valid_0's custom_score: 0.777401
# [5000]	valid_0's custom_score: 0.777618
# [5200]	valid_0's custom_score: 0.777783
# [5400]	valid_0's custom_score: 0.776914
# [5600]	valid_0's custom_score: 0.776128
# [5800]	valid_0's custom_score: 0.776746
# Learning rate adjusted to 0.045000000000000005
# [6000]	valid_0's custom_score: 0.777754
# [6200]	valid_0's custom_score: 0.777326
# [6400]	valid_0's custom_score: 0.776668
# [6600]	valid_0's custom_score: 0.776501
# [6800]	valid_0's custom_score: 0.778415
# [7000]	valid_0's custom_score: 0.778675
# [7200]	valid_0's custom_score: 0.777425
# [7400]	valid_0's custom_score: 0.777231
# [7600]	valid_0's custom_score: 0.775613
# [7800]	valid_0's custom_score: 0.775224
# Learning rate adjusted to 0.04050000000000001
# [8000]	valid_0's custom_score: 0.775604
# [8200]	valid_0's custom_score: 0.776401
# [8400]	valid_0's custom_score: 0.776777
# [8600]	valid_0's custom_score: 0.776738
# [8800]	valid_0's custom_score: 0.776559
# Learning rate adjusted to 0.03645000000000001
# [9000]	valid_0's custom_score: 0.776488
# [9200]	valid_0's custom_score: 0.775839
# [9400]	valid_0's custom_score: 0.775784
# Early stopping, best iteration is:
# [6945]	valid_0's custom_score: 0.778703
# Evaluated only: custom_score
# Fold 3 best valid score: 0.7787027472564964
# Starting fold 4
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.699421
# [400]	valid_0's custom_score: 0.726607
# [600]	valid_0's custom_score: 0.741762
# [800]	valid_0's custom_score: 0.744843
# [1000]	valid_0's custom_score: 0.752021
# [1200]	valid_0's custom_score: 0.756634
# [1400]	valid_0's custom_score: 0.760457
# [1600]	valid_0's custom_score: 0.761917
# [1800]	valid_0's custom_score: 0.764934
# [2000]	valid_0's custom_score: 0.764873
# [2200]	valid_0's custom_score: 0.766977
# [2400]	valid_0's custom_score: 0.769534
# [2600]	valid_0's custom_score: 0.771373
# [2800]	valid_0's custom_score: 0.771827
# [3000]	valid_0's custom_score: 0.771412
# [3200]	valid_0's custom_score: 0.774921
# [3400]	valid_0's custom_score: 0.773946
# [3600]	valid_0's custom_score: 0.774097
# [3800]	valid_0's custom_score: 0.77501
# [4000]	valid_0's custom_score: 0.776087
# [4200]	valid_0's custom_score: 0.776507
# [4400]	valid_0's custom_score: 0.776169
# [4600]	valid_0's custom_score: 0.777035
# [4800]	valid_0's custom_score: 0.776557
# [5000]	valid_0's custom_score: 0.777245
# [5200]	valid_0's custom_score: 0.77715
# [5400]	valid_0's custom_score: 0.776669
# [5600]	valid_0's custom_score: 0.77606
# Learning rate adjusted to 0.045000000000000005
# [5800]	valid_0's custom_score: 0.77585
# [6000]	valid_0's custom_score: 0.775732
# [6200]	valid_0's custom_score: 0.777117
# [6400]	valid_0's custom_score: 0.776341
# [6600]	valid_0's custom_score: 0.777
# Learning rate adjusted to 0.04050000000000001
# [6800]	valid_0's custom_score: 0.776058
# [7000]	valid_0's custom_score: 0.776247
# Early stopping, best iteration is:
# [4665]	valid_0's custom_score: 0.777962
# Evaluated only: custom_score
# Fold 4 best valid score: 0.777962112618803
# Starting fold 5
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.69347
# [400]	valid_0's custom_score: 0.715851
# [600]	valid_0's custom_score: 0.729376
# [800]	valid_0's custom_score: 0.740132
# [1000]	valid_0's custom_score: 0.74717
# [1200]	valid_0's custom_score: 0.751788
# [1400]	valid_0's custom_score: 0.754336
# [1600]	valid_0's custom_score: 0.755919
# [1800]	valid_0's custom_score: 0.757819
# [2000]	valid_0's custom_score: 0.760581
# [2200]	valid_0's custom_score: 0.763129
# [2400]	valid_0's custom_score: 0.763323
# [2600]	valid_0's custom_score: 0.76573
# [2800]	valid_0's custom_score: 0.767627
# [3000]	valid_0's custom_score: 0.770202
# [3200]	valid_0's custom_score: 0.769744
# [3400]	valid_0's custom_score: 0.770768
# [3600]	valid_0's custom_score: 0.771491
# [3800]	valid_0's custom_score: 0.772926
# [4000]	valid_0's custom_score: 0.771966
# [4200]	valid_0's custom_score: 0.770795
# [4400]	valid_0's custom_score: 0.771671
# [4600]	valid_0's custom_score: 0.770036
# Learning rate adjusted to 0.045000000000000005
# [4800]	valid_0's custom_score: 0.769907
# [5000]	valid_0's custom_score: 0.770408
# [5200]	valid_0's custom_score: 0.770235
# [5400]	valid_0's custom_score: 0.769816
# [5600]	valid_0's custom_score: 0.770723
# Learning rate adjusted to 0.04050000000000001
# [5800]	valid_0's custom_score: 0.771065
# [6000]	valid_0's custom_score: 0.770258
# Early stopping, best iteration is:
# [3685]	valid_0's custom_score: 0.773007
# Evaluated only: custom_score
# Fold 5 best valid score: 0.7730071137340517
# Starting fold 6
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.695912
# [400]	valid_0's custom_score: 0.72704
# [600]	valid_0's custom_score: 0.734165
# [800]	valid_0's custom_score: 0.743637
# [1000]	valid_0's custom_score: 0.749031
# [1200]	valid_0's custom_score: 0.755098
# [1400]	valid_0's custom_score: 0.758982
# [1600]	valid_0's custom_score: 0.764147
# [1800]	valid_0's custom_score: 0.766062
# [2000]	valid_0's custom_score: 0.767367
# [2200]	valid_0's custom_score: 0.768101
# [2400]	valid_0's custom_score: 0.770688
# [2600]	valid_0's custom_score: 0.771621
# [2800]	valid_0's custom_score: 0.772313
# [3000]	valid_0's custom_score: 0.770962
# [3200]	valid_0's custom_score: 0.77386
# [3400]	valid_0's custom_score: 0.773161
# [3600]	valid_0's custom_score: 0.773317
# [3800]	valid_0's custom_score: 0.77438
# [4000]	valid_0's custom_score: 0.773238
# [4200]	valid_0's custom_score: 0.774204
# [4400]	valid_0's custom_score: 0.776252
# [4600]	valid_0's custom_score: 0.776554
# [4800]	valid_0's custom_score: 0.776796
# [5000]	valid_0's custom_score: 0.776952
# [5200]	valid_0's custom_score: 0.777049
# [5400]	valid_0's custom_score: 0.778195
# [5600]	valid_0's custom_score: 0.77732
# [5800]	valid_0's custom_score: 0.777879
# [6000]	valid_0's custom_score: 0.777445
# [6200]	valid_0's custom_score: 0.776748
# [6400]	valid_0's custom_score: 0.778122
# [6600]	valid_0's custom_score: 0.778746
# [6800]	valid_0's custom_score: 0.778785
# [7000]	valid_0's custom_score: 0.779528
# [7200]	valid_0's custom_score: 0.779438
# [7400]	valid_0's custom_score: 0.779109
# [7600]	valid_0's custom_score: 0.779161
# [7800]	valid_0's custom_score: 0.779356
# [8000]	valid_0's custom_score: 0.779273
# [8200]	valid_0's custom_score: 0.779604
# [8400]	valid_0's custom_score: 0.78061
# [8600]	valid_0's custom_score: 0.780496
# [8800]	valid_0's custom_score: 0.78202
# [9000]	valid_0's custom_score: 0.782902
# [9200]	valid_0's custom_score: 0.783578
# [9400]	valid_0's custom_score: 0.783527
# [9600]	valid_0's custom_score: 0.78278
# [9800]	valid_0's custom_score: 0.783592
# [10000]	valid_0's custom_score: 0.782905
# Learning rate adjusted to 0.045000000000000005
# [10200]	valid_0's custom_score: 0.782959
# [10400]	valid_0's custom_score: 0.782868
# [10600]	valid_0's custom_score: 0.782525
# [10800]	valid_0's custom_score: 0.782018
# [11000]	valid_0's custom_score: 0.782061
# Learning rate adjusted to 0.04050000000000001
# [11200]	valid_0's custom_score: 0.781961
# [11400]	valid_0's custom_score: 0.781472
# [11600]	valid_0's custom_score: 0.782165
# Early stopping, best iteration is:
# [9100]	valid_0's custom_score: 0.783965
# Evaluated only: custom_score
# Fold 6 best valid score: 0.7839646276617024
# Starting fold 7
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.691277
# [400]	valid_0's custom_score: 0.710963
# [600]	valid_0's custom_score: 0.727478
# [800]	valid_0's custom_score: 0.736602
# [1000]	valid_0's custom_score: 0.739103
# [1200]	valid_0's custom_score: 0.746222
# [1400]	valid_0's custom_score: 0.750035
# [1600]	valid_0's custom_score: 0.756042
# [1800]	valid_0's custom_score: 0.757836
# [2000]	valid_0's custom_score: 0.759093
# [2200]	valid_0's custom_score: 0.76199
# [2400]	valid_0's custom_score: 0.761211
# [2600]	valid_0's custom_score: 0.761558
# [2800]	valid_0's custom_score: 0.762358
# [3000]	valid_0's custom_score: 0.761794
# [3200]	valid_0's custom_score: 0.762469
# [3400]	valid_0's custom_score: 0.76155
# [3600]	valid_0's custom_score: 0.761306
# [3800]	valid_0's custom_score: 0.762226
# [4000]	valid_0's custom_score: 0.76112
# Learning rate adjusted to 0.045000000000000005
# [4200]	valid_0's custom_score: 0.764302
# [4400]	valid_0's custom_score: 0.763204
# [4600]	valid_0's custom_score: 0.762516
# [4800]	valid_0's custom_score: 0.76158
# [5000]	valid_0's custom_score: 0.760336
# Learning rate adjusted to 0.04050000000000001
# [5200]	valid_0's custom_score: 0.761315
# [5400]	valid_0's custom_score: 0.762846
# [5600]	valid_0's custom_score: 0.761752
# [5800]	valid_0's custom_score: 0.761129
# [6000]	valid_0's custom_score: 0.761698
# Learning rate adjusted to 0.03645000000000001
# [6200]	valid_0's custom_score: 0.761839
# [6400]	valid_0's custom_score: 0.76215
# [6600]	valid_0's custom_score: 0.762346
# Early stopping, best iteration is:
# [4184]	valid_0's custom_score: 0.764323
# Evaluated only: custom_score
# Fold 7 best valid score: 0.7643228222905245
# Starting fold 8
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.70543
# [400]	valid_0's custom_score: 0.73551
# [600]	valid_0's custom_score: 0.745843
# [800]	valid_0's custom_score: 0.757772
# [1000]	valid_0's custom_score: 0.766496
# [1200]	valid_0's custom_score: 0.771424
# [1400]	valid_0's custom_score: 0.770877
# [1600]	valid_0's custom_score: 0.775257
# [1800]	valid_0's custom_score: 0.776962
# [2000]	valid_0's custom_score: 0.77785
# [2200]	valid_0's custom_score: 0.776903
# [2400]	valid_0's custom_score: 0.77785
# [2600]	valid_0's custom_score: 0.776904
# [2800]	valid_0's custom_score: 0.777268
# [3000]	valid_0's custom_score: 0.779001
# [3200]	valid_0's custom_score: 0.779348
# [3400]	valid_0's custom_score: 0.778591
# [3600]	valid_0's custom_score: 0.779513
# [3800]	valid_0's custom_score: 0.779991
# [4000]	valid_0's custom_score: 0.778869
# Learning rate adjusted to 0.045000000000000005
# [4200]	valid_0's custom_score: 0.780142
# [4400]	valid_0's custom_score: 0.780055
# [4600]	valid_0's custom_score: 0.780117
# [4800]	valid_0's custom_score: 0.778254
# [5000]	valid_0's custom_score: 0.777847
# Learning rate adjusted to 0.04050000000000001
# [5200]	valid_0's custom_score: 0.778134
# [5400]	valid_0's custom_score: 0.777764
# Early stopping, best iteration is:
# [3061]	valid_0's custom_score: 0.781276
# Evaluated only: custom_score
# Fold 8 best valid score: 0.7812759917064054
# Starting fold 9
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.704583
# [400]	valid_0's custom_score: 0.726297
# [600]	valid_0's custom_score: 0.738901
# [800]	valid_0's custom_score: 0.74377
# [1000]	valid_0's custom_score: 0.751203
# [1200]	valid_0's custom_score: 0.755171
# [1400]	valid_0's custom_score: 0.759166
# [1600]	valid_0's custom_score: 0.759641
# [1800]	valid_0's custom_score: 0.75816
# [2000]	valid_0's custom_score: 0.759223
# [2200]	valid_0's custom_score: 0.758958
# [2400]	valid_0's custom_score: 0.761736
# [2600]	valid_0's custom_score: 0.761837
# [2800]	valid_0's custom_score: 0.762748
# [3000]	valid_0's custom_score: 0.764827
# [3200]	valid_0's custom_score: 0.765429
# [3400]	valid_0's custom_score: 0.764866
# [3600]	valid_0's custom_score: 0.765181
# [3800]	valid_0's custom_score: 0.767109
# [4000]	valid_0's custom_score: 0.763725
# [4200]	valid_0's custom_score: 0.762843
# [4400]	valid_0's custom_score: 0.76246
# [4600]	valid_0's custom_score: 0.763305
# [4800]	valid_0's custom_score: 0.760632
# Learning rate adjusted to 0.045000000000000005
# [5000]	valid_0's custom_score: 0.76125
# [5200]	valid_0's custom_score: 0.762437
# [5400]	valid_0's custom_score: 0.761142
# [5600]	valid_0's custom_score: 0.761579
# [5800]	valid_0's custom_score: 0.76204
# Learning rate adjusted to 0.04050000000000001
# [6000]	valid_0's custom_score: 0.762673
# [6200]	valid_0's custom_score: 0.761722
# Early stopping, best iteration is:
# [3842]	valid_0's custom_score: 0.767522
# Evaluated only: custom_score
# Fold 9 best valid score: 0.7675220450014184
# Starting fold 10
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.697806
# [400]	valid_0's custom_score: 0.719629
# [600]	valid_0's custom_score: 0.729235
# [800]	valid_0's custom_score: 0.737698
# [1000]	valid_0's custom_score: 0.746536
# [1200]	valid_0's custom_score: 0.75126
# [1400]	valid_0's custom_score: 0.75472
# [1600]	valid_0's custom_score: 0.75778
# [1800]	valid_0's custom_score: 0.764414
# [2000]	valid_0's custom_score: 0.767963
# [2200]	valid_0's custom_score: 0.768814
# [2400]	valid_0's custom_score: 0.770638
# [2600]	valid_0's custom_score: 0.774016
# [2800]	valid_0's custom_score: 0.775771
# [3000]	valid_0's custom_score: 0.777396
# [3200]	valid_0's custom_score: 0.778854
# [3400]	valid_0's custom_score: 0.779777
# [3600]	valid_0's custom_score: 0.779473
# [3800]	valid_0's custom_score: 0.7809
# [4000]	valid_0's custom_score: 0.78078
# [4200]	valid_0's custom_score: 0.780237
# [4400]	valid_0's custom_score: 0.779551
# [4600]	valid_0's custom_score: 0.782097
# [4800]	valid_0's custom_score: 0.782059
# [5000]	valid_0's custom_score: 0.782703
# [5200]	valid_0's custom_score: 0.783519
# [5400]	valid_0's custom_score: 0.783722
# [5600]	valid_0's custom_score: 0.782783
# [5800]	valid_0's custom_score: 0.782814
# [6000]	valid_0's custom_score: 0.782472
# [6200]	valid_0's custom_score: 0.782795
# Learning rate adjusted to 0.045000000000000005
# [6400]	valid_0's custom_score: 0.781012
# [6600]	valid_0's custom_score: 0.781367
# [6800]	valid_0's custom_score: 0.782159
# [7000]	valid_0's custom_score: 0.781295
# [7200]	valid_0's custom_score: 0.782609
# Learning rate adjusted to 0.04050000000000001
# [7400]	valid_0's custom_score: 0.782712
# [7600]	valid_0's custom_score: 0.782244
# [7800]	valid_0's custom_score: 0.78158
# Early stopping, best iteration is:
# [5331]	valid_0's custom_score: 0.784264
# Evaluated only: custom_score
# Fold 10 best valid score: 0.7842642957661983

# %%
# 预测并保存结果
y_pred = np.mean([gbm.predict(feats.iloc[n_original:, :-1]) for gbm in trained_gbms], axis=0)

# %%
df_submit["mRNA_remaining_pct"] = y_pred
df_submit.to_csv("submission.csv", index=False)
